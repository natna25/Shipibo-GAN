# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

os.chdir("/content/drive/My Drive/GAN/Shipibo GAN/")
# !ls
# Out:
# Mounted at /content/drive
# 'Copy of Shipibo gan test 1.ipynb'   test_gif_2.mp4
#  preproc			     test_gif_3.mp4
# 'Shipibo gan test 1.ipynb'	     train_grid.mp4
# 'shipibo test gan 32.ipynb'

# %%
from keras.preprocessing.image import load_img,img_to_array
from PIL import Image

def load_images(path):
    """ loads images into a numpy array and returns them
    """
    img_paths = [path + f  for f in os.listdir(path)]
    print(len(img_paths))
    dataset_shape = (len(img_paths),64,64,3)

    data = np.ndarray(shape=dataset_shape)

    for i,f in enumerate(os.listdir(path)):
        im = Image.open(path + f)
        
        im = np.array(im)
        
        if i % 20 == 0:
            print("loaded ", i,"images" )

        data[i] = im.astype(int)
        

    print(data.shape)

    return data
data = load_images("preproc/overfit/")
# Out:
# Using TensorFlow backend.
# 1
# loaded  0 images
# (1, 64, 64, 3)

# %%
#warning, only run this once or else load the data all over again
data = (data - 127.5) / 127.5

# %%
test = (data[0] + 1) / 2.0
plt.imshow(test)

# %%
def generate_real_samples(data,n_samples):
    
    rand_indexes = np.random.randint(0,data.shape[0],n_samples)
    
    X_samples = data[rand_indexes]
    y_samples = np.ones((n_samples,1))
    
    return X_samples,y_samples

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Conv2D
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers import LeakyReLU
from keras.optimizers import Adam

def make_discriminator(input_shape=(64,64,3)):
    
    model = Sequential()
    #normal layer
    model.add(Conv2D(64,(3,3),padding="same",input_shape=input_shape))
    model.add(LeakyReLU(alpha=0.2))
    
    #downsample
    model.add(Conv2D(128,(3,3),strides=(2,2),padding="same"))
    
    model.add(LeakyReLU(alpha=0.2))
    
    #downsample
    model.add(Conv2D(128,(3,3),strides=(2,2),padding="same"))
    model.add(LeakyReLU(alpha=0.2))
    
    #downsample
    model.add(Conv2D(256,(3,3),strides=(2,2),padding="same"))
    model.add(LeakyReLU(alpha=0.2))

    #downsample
    model.add(Conv2D(256,(3,3),strides=(2,2),padding="same"))
    model.add(LeakyReLU(alpha=0.2))
    
    #flatten then pass through fully connected layer
    model.add(Flatten())
    model.add(Dropout(0.4))
    model.add(Dense(1,activation="sigmoid"))
    
    opt = Adam(lr=0.0002,beta_1=0.5)
    
    model.compile(loss="binary_crossentropy",optimizer=opt,metrics=["accuracy"])
    
    return model

# %%
from keras.layers import Reshape
from keras.layers import Conv2DTranspose

# define the standalone generator model
def make_generator(latent_dim=100):
    model = Sequential()
    # foundation for 4x4 image
    n_nodes = 256 * 4 * 4
    model.add(Dense(n_nodes, input_dim=latent_dim))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Reshape((4, 4, 256)))
    # upsample to 8x8
    model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    # upsample to 16x16
    model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    # upsample to 32x32
    model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    #upsample to 64x64
    model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    # output layer
    model.add(Conv2D(3, (3,3), activation='tanh', padding='same'))
    return model

# %%
def generate_latent_points(n_samples,latent_dim=100):
    
    latent_points = np.random.randn(latent_dim*n_samples)
    
    latent_points = latent_points.reshape((n_samples,latent_dim))
    
    return latent_points

def generate_fake_samples(generator,n_samples,latent_dim=100):
    
    #first generate latent points, then pass them to the generator
    
    latent_points = generate_latent_points(n_samples,latent_dim)
    
    X_fake = generator.predict(latent_points)
    
    y_fake = np.zeros((n_samples,1))
    
    return X_fake,y_fake

# %%
def make_gan(discriminator,generator):
    
    model = Sequential()
    
    discriminator.trainable = False
    
    model.add(generator)
    
    model.add(discriminator)
    
    opt = Adam(lr=0.0002, beta_1=0.5)
    model.compile(loss="binary_crossentropy",optimizer=opt)
    
    return model

# %%
import time

def train_gan(data,gan,discriminator,generator,n_epochs=200,batch_size=128):
    batch_per_epoch = 2
    half_batch = int(batch_size / 2)
    
    n_points = 9
    fixed_latent_points = generate_latent_points(n_points)
    train_images = []
    
    gan_loss = []
    disc_loss = []
    
    
    for epoch in range(n_epochs):
        print("starting epoch",epoch)
        start_time = time.time()
        
        avg_epoch_disc_loss= []
        avg_epoch_gen_loss = []

        for batch in range(batch_per_epoch):
            
            #train the discriminator
            X_real,y_real = generate_real_samples(data,half_batch)
            X_fake,y_fake = generate_fake_samples(generator,half_batch)
            
            X,y = np.vstack((X_real,X_fake)) , np.vstack((y_real, y_fake))
            
            d_loss, _ = discriminator.train_on_batch(X,y)
            
            #train the generator (through the gan model by using the discriminator's error)
            lat_points = generate_latent_points(batch_size)
            y_gan = np.ones((batch_size,1))
            
            g_loss = gan.train_on_batch(lat_points,y_gan)
            
            
            #paint some pictures
            if batch % 1 == 0:
                imgs = generator.predict(fixed_latent_points)

                #renormalize images for easy printing
                imgs = (imgs + 1) / 2.0
                train_images.append(imgs)
                
                #add loss to storage for graphing
                
                gan_loss.append(g_loss)
                disc_loss.append(d_loss)
            
            avg_epoch_disc_loss.append(d_loss)
            avg_epoch_gen_loss.append(g_loss)

        stop_time = time.time()
        print("avg loss over epoch, \nDiscriminator:" ,sum(avg_epoch_disc_loss)/len(avg_epoch_disc_loss),"\nGenerator:",sum(avg_epoch_gen_loss)/len(avg_epoch_gen_loss))
        print("epoch",epoch,"finished in",stop_time - start_time,"s\n\n")
            
            
    return train_images,gan_loss,disc_loss


reset_train = False

if reset_train:    
    discriminator = make_discriminator()
    generator = make_generator()

    gan = make_gan(discriminator,generator)



train_images,gan_loss,disc_loss = train_gan(data,gan,discriminator,generator,n_epochs=100)
# Out:
# starting epoch 0
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# avg loss over epoch,
# Discriminator: 0.3167109489440918
# Generator: 2.043449819087982
# epoch 0 finished in 1.3515145778656006 s
#
#
# starting epoch 1
# avg loss over epoch,
# Discriminator: 0.2815665155649185
# Generator: 2.169723629951477
# epoch 1 finished in 1.2823846340179443 s
#
#
# starting epoch 2
# avg loss over epoch,
# Discriminator: 0.22507602721452713
# Generator: 2.035833477973938
# epoch 2 finished in 1.2743732929229736 s
#
#
# starting epoch 3
# avg loss over epoch,
# Discriminator: 0.21481283009052277
# Generator: 1.9617536664009094
# epoch 3 finished in 1.2823996543884277 s
#
#
# starting epoch 4
# avg loss over epoch,
# Discriminator: 0.24679679423570633
# Generator: 1.883508026599884
# epoch 4 finished in 1.2848396301269531 s
#
#
# starting epoch 5
# avg loss over epoch,
# Discriminator: 0.23722687363624573
# Generator: 1.8075976371765137
# epoch 5 finished in 1.2857751846313477 s
#
#
# starting epoch 6
# avg loss over epoch,
# Discriminator: 0.30040600895881653
# Generator: 1.4218752831220627
# epoch 6 finished in 1.285229206085205 s
#
#
# starting epoch 7
# avg loss over epoch,
# Discriminator: 0.7434757649898529
# Generator: 2.465309977531433
# epoch 7 finished in 1.2867016792297363 s
#
#
# starting epoch 8
# avg loss over epoch,
# Discriminator: 0.5546133741736412
# Generator: 2.4668407440185547
# epoch 8 finished in 1.2828843593597412 s
#
#
# starting epoch 9
# avg loss over epoch,
# Discriminator: 0.29253236949443817
# Generator: 1.7570242285728455
# epoch 9 finished in 1.2963125705718994 s
#
#
# starting epoch 10
# avg loss over epoch,
# Discriminator: 0.250324122607708
# Generator: 1.8666645288467407
# epoch 10 finished in 1.2835519313812256 s
#
#
# starting epoch 11
# avg loss over epoch,
# Discriminator: 0.25377700477838516
# Generator: 1.8520971536636353
# epoch 11 finished in 1.2832860946655273 s
#
#
# starting epoch 12
# avg loss over epoch,
# Discriminator: 0.2648444175720215
# Generator: 1.723965048789978
# epoch 12 finished in 1.2803597450256348 s
#
#
# starting epoch 13
# avg loss over epoch,
# Discriminator: 0.27783381938934326
# Generator: 1.6367185711860657
# epoch 13 finished in 1.288785696029663 s
#
#
# starting epoch 14
# avg loss over epoch,
# Discriminator: 0.26735448837280273
# Generator: 1.7801665663719177
# epoch 14 finished in 1.2846693992614746 s
#
#
# starting epoch 15
# avg loss over epoch,
# Discriminator: 0.29351024329662323
# Generator: 1.8920084238052368
# epoch 15 finished in 1.286407232284546 s
#
#
# starting epoch 16
# avg loss over epoch,
# Discriminator: 0.44913241267204285
# Generator: 1.9187641143798828
# epoch 16 finished in 1.28285813331604 s
#
#
# starting epoch 17
# avg loss over epoch,
# Discriminator: 0.61053466796875
# Generator: 1.3921836018562317
# epoch 17 finished in 1.2869939804077148 s
#
#
# starting epoch 18
# avg loss over epoch,
# Discriminator: 0.3251577615737915
# Generator: 1.4203210473060608
# epoch 18 finished in 1.2845714092254639 s
#
#
# starting epoch 19
# avg loss over epoch,
# Discriminator: 0.3307526409626007
# Generator: 1.7221885919570923
# epoch 19 finished in 1.2830426692962646 s
#
#
# starting epoch 20
# avg loss over epoch,
# Discriminator: 0.25984425097703934
# Generator: 1.8886024355888367
# epoch 20 finished in 1.284909963607788 s
#
#
# starting epoch 21
# avg loss over epoch,
# Discriminator: 0.2188205048441887
# Generator: 2.097736656665802
# epoch 21 finished in 1.2956337928771973 s
#
#
# starting epoch 22
# avg loss over epoch,
# Discriminator: 0.2689489275217056
# Generator: 1.9286596775054932
# epoch 22 finished in 1.2853693962097168 s
#
#
# starting epoch 23
# avg loss over epoch,
# Discriminator: 0.3381006568670273
# Generator: 1.7413864731788635
# epoch 23 finished in 1.2833774089813232 s
#
#
# starting epoch 24
# avg loss over epoch,
# Discriminator: 0.4199531525373459
# Generator: 1.6252292394638062
# epoch 24 finished in 1.2829883098602295 s
#
#
# starting epoch 25
# avg loss over epoch,
# Discriminator: 0.41616488993167877
# Generator: 1.454303503036499
# epoch 25 finished in 1.2822425365447998 s
#
#
# starting epoch 26
# avg loss over epoch,
# Discriminator: 0.3331338167190552
# Generator: 1.470292091369629
# epoch 26 finished in 1.2863061428070068 s
#
#
# starting epoch 27
# avg loss over epoch,
# Discriminator: 0.27521269023418427
# Generator: 1.5988790392875671
# epoch 27 finished in 1.286952257156372 s
#
#
# starting epoch 28
# avg loss over epoch,
# Discriminator: 0.28326620161533356
# Generator: 1.619091510772705
# epoch 28 finished in 1.2735621929168701 s
#
#
# starting epoch 29
# avg loss over epoch,
# Discriminator: 0.19003575295209885
# Generator: 1.8248111605644226
# epoch 29 finished in 1.2804741859436035 s
#
#
# starting epoch 30
# avg loss over epoch,
# Discriminator: 0.3904489427804947
# Generator: 1.9412665367126465
# epoch 30 finished in 1.281757116317749 s
#
#
# starting epoch 31
# avg loss over epoch,
# Discriminator: 0.4318822771310806
# Generator: 2.769755482673645
# epoch 31 finished in 1.2795171737670898 s
#
#
# starting epoch 32
# avg loss over epoch,
# Discriminator: 0.35147619247436523
# Generator: 1.7683182954788208
# epoch 32 finished in 1.282485008239746 s
#
#
# starting epoch 33
# avg loss over epoch,
# Discriminator: 0.30440160632133484
# Generator: 1.813553810119629
# epoch 33 finished in 1.28340482711792 s
#
#
# starting epoch 34
# avg loss over epoch,
# Discriminator: 0.35967789590358734
# Generator: 1.5929939150810242
# epoch 34 finished in 1.285628080368042 s
#
#
# starting epoch 35
# avg loss over epoch,
# Discriminator: 0.41635464131832123
# Generator: 1.6428325474262238
# epoch 35 finished in 1.2880730628967285 s
#
#
# starting epoch 36
# avg loss over epoch,
# Discriminator: 0.40637554228305817
# Generator: 1.5561328530311584
# epoch 36 finished in 1.2871670722961426 s
#
#
# starting epoch 37
# avg loss over epoch,
# Discriminator: 0.39640915393829346
# Generator: 1.4598431587219238
# epoch 37 finished in 1.2797820568084717 s
#
#
# starting epoch 38
# avg loss over epoch,
# Discriminator: 0.35434114933013916
# Generator: 1.5305049419403076
# epoch 38 finished in 1.2781455516815186 s
#
#
# starting epoch 39
# avg loss over epoch,
# Discriminator: 0.373109370470047
# Generator: 1.62070831656456
# epoch 39 finished in 1.2812931537628174 s
#
#
# starting epoch 40
# avg loss over epoch,
# Discriminator: 0.38336479663848877
# Generator: 1.5395317077636719
# epoch 40 finished in 1.2950942516326904 s
#
#
# starting epoch 41
# avg loss over epoch,
# Discriminator: 0.37392041087150574
# Generator: 1.4828877449035645
# epoch 41 finished in 1.2916769981384277 s
#
#
# starting epoch 42
# avg loss over epoch,
# Discriminator: 0.32414737343788147
# Generator: 1.485055148601532
# epoch 42 finished in 1.3058300018310547 s
#
#
# starting epoch 43
# avg loss over epoch,
# Discriminator: 0.2772967666387558
# Generator: 1.6703793406486511
# epoch 43 finished in 1.294567584991455 s
#
#
# starting epoch 44
# avg loss over epoch,
# Discriminator: 0.2448837161064148
# Generator: 1.794473946094513
# epoch 44 finished in 1.2993602752685547 s
#
#
# starting epoch 45
# avg loss over epoch,
# Discriminator: 0.4881489872932434
# Generator: 1.6581719294190407
# epoch 45 finished in 1.2964680194854736 s
#
#
# starting epoch 46
# avg loss over epoch,
# Discriminator: 0.5797216892242432
# Generator: 2.3254969120025635
# epoch 46 finished in 1.294790267944336 s
#
#
# starting epoch 47
# avg loss over epoch,
# Discriminator: 0.3229612112045288
# Generator: 1.5689422488212585
# epoch 47 finished in 1.2973225116729736 s
#
#
# starting epoch 48
# avg loss over epoch,
# Discriminator: 0.3731064796447754
# Generator: 1.7546886205673218
# epoch 48 finished in 1.294478416442871 s
#
#
# starting epoch 49
# avg loss over epoch,
# Discriminator: 0.43225836753845215
# Generator: 1.6379965841770172
# epoch 49 finished in 1.2876768112182617 s
#
#
# starting epoch 50
# avg loss over epoch,
# Discriminator: 0.4328197240829468
# Generator: 1.4152305722236633
# epoch 50 finished in 1.2982795238494873 s
#
#
# starting epoch 51
# avg loss over epoch,
# Discriminator: 0.402742937207222
# Generator: 1.4277269840240479
# epoch 51 finished in 1.2943713665008545 s
#
#
# starting epoch 52
# avg loss over epoch,
# Discriminator: 0.3827068507671356
# Generator: 1.48587366938591
# epoch 52 finished in 1.2947776317596436 s
#
#
# starting epoch 53
# avg loss over epoch,
# Discriminator: 0.44700631499290466
# Generator: 1.6018163561820984
# epoch 53 finished in 1.293752908706665 s
#
#
# starting epoch 54
# avg loss over epoch,
# Discriminator: 0.5374662727117538
# Generator: 1.2305737733840942
# epoch 54 finished in 1.2994749546051025 s
#
#
# starting epoch 55
# avg loss over epoch,
# Discriminator: 0.3987881690263748
# Generator: 1.2259267568588257
# epoch 55 finished in 1.2911794185638428 s
#
#
# starting epoch 56
# avg loss over epoch,
# Discriminator: 0.36629265546798706
# Generator: 1.492597222328186
# epoch 56 finished in 1.293541431427002 s
#
#
# starting epoch 57
# avg loss over epoch,
# Discriminator: 0.3634866327047348
# Generator: 1.43293035030365
# epoch 57 finished in 1.2911689281463623 s
#
#
# starting epoch 58
# avg loss over epoch,
# Discriminator: 0.3801967054605484
# Generator: 1.6910169124603271
# epoch 58 finished in 1.3043951988220215 s
#
#
# starting epoch 59
# avg loss over epoch,
# Discriminator: 0.5141641199588776
# Generator: 1.5476881563663483
# epoch 59 finished in 1.2944185733795166 s
#
#
# starting epoch 60
# avg loss over epoch,
# Discriminator: 0.5151725709438324
# Generator: 1.5215475261211395
# epoch 60 finished in 1.2996151447296143 s
#
#
# starting epoch 61
# avg loss over epoch,
# Discriminator: 0.38905853033065796
# Generator: 1.2740890383720398
# epoch 61 finished in 1.2912812232971191 s
#
#
# starting epoch 62
# avg loss over epoch,
# Discriminator: 0.4381858557462692
# Generator: 1.1596797704696655
# epoch 62 finished in 1.305211067199707 s
#
#
# starting epoch 63
# avg loss over epoch,
# Discriminator: 0.47149762511253357
# Generator: 1.3660655617713928
# epoch 63 finished in 1.3049955368041992 s
#
#
# starting epoch 64
# avg loss over epoch,
# Discriminator: 0.47296957671642303
# Generator: 1.3324536085128784
# epoch 64 finished in 1.2960162162780762 s
#
#
# starting epoch 65
# avg loss over epoch,
# Discriminator: 0.44872403144836426
# Generator: 1.3318783342838287
# epoch 65 finished in 1.2933969497680664 s
#
#
# starting epoch 66
# avg loss over epoch,
# Discriminator: 0.47407764196395874
# Generator: 1.3492048382759094
# epoch 66 finished in 1.2897958755493164 s
#
#
# starting epoch 67
# avg loss over epoch,
# Discriminator: 0.5407407134771347
# Generator: 1.4228161573410034
# epoch 67 finished in 1.3144619464874268 s
#
#
# starting epoch 68
# avg loss over epoch,
# Discriminator: 0.3965442478656769
# Generator: 1.374599277973175
# epoch 68 finished in 1.299241304397583 s
#
#
# starting epoch 69
# avg loss over epoch,
# Discriminator: 0.370766818523407
# Generator: 1.5313845872879028
# epoch 69 finished in 1.286245584487915 s
#
#
# starting epoch 70
# avg loss over epoch,
# Discriminator: 0.41074496507644653
# Generator: 1.881331205368042
# epoch 70 finished in 1.2832286357879639 s
#
#
# starting epoch 71
# avg loss over epoch,
# Discriminator: 0.6457393169403076
# Generator: 1.1750747859477997
# epoch 71 finished in 1.2797935009002686 s
#
#
# starting epoch 72
# avg loss over epoch,
# Discriminator: 0.40005041658878326
# Generator: 1.6198140382766724
# epoch 72 finished in 1.282747745513916 s
#
#
# starting epoch 73
# avg loss over epoch,
# Discriminator: 0.4354443848133087
# Generator: 1.1830661594867706
# epoch 73 finished in 1.2839229106903076 s
#
#
# starting epoch 74
# avg loss over epoch,
# Discriminator: 0.47501179575920105
# Generator: 1.2368965148925781
# epoch 74 finished in 1.2871220111846924 s
#
#
# starting epoch 75
# avg loss over epoch,
# Discriminator: 0.5534184873104095
# Generator: 1.2247157990932465
# epoch 75 finished in 1.2856299877166748 s
#
#
# starting epoch 76
# avg loss over epoch,
# Discriminator: 0.574643462896347
# Generator: 1.308387815952301
# epoch 76 finished in 1.2835705280303955 s
#
#
# starting epoch 77
# avg loss over epoch,
# Discriminator: 0.46188920736312866
# Generator: 1.3015615344047546
# epoch 77 finished in 1.2855138778686523 s
#
#
# starting epoch 78
# avg loss over epoch,
# Discriminator: 0.47262462973594666
# Generator: 1.2291661500930786
# epoch 78 finished in 1.2758815288543701 s
#
#
# starting epoch 79
# avg loss over epoch,
# Discriminator: 0.4803881049156189
# Generator: 1.3683695793151855
# epoch 79 finished in 1.282118797302246 s
#
#
# starting epoch 80
# avg loss over epoch,
# Discriminator: 0.6524607837200165
# Generator: 1.1122461557388306
# epoch 80 finished in 1.2857029438018799 s
#
#
# starting epoch 81
# avg loss over epoch,
# Discriminator: 0.500855952501297
# Generator: 1.3349215984344482
# epoch 81 finished in 1.277430534362793 s
#
#
# starting epoch 82
# avg loss over epoch,
# Discriminator: 0.4614993631839752
# Generator: 1.0978223085403442
# epoch 82 finished in 1.281224012374878 s
#
#
# starting epoch 83
# avg loss over epoch,
# Discriminator: 0.5182154178619385
# Generator: 1.1076204180717468
# epoch 83 finished in 1.2767248153686523 s
#
#
# starting epoch 84
# avg loss over epoch,
# Discriminator: 0.6400452852249146
# Generator: 1.2906258404254913
# epoch 84 finished in 1.281353235244751 s
#
#
# starting epoch 85
# avg loss over epoch,
# Discriminator: 0.6142265498638153
# Generator: 1.2938228249549866
# epoch 85 finished in 1.2814173698425293 s
#
#
# starting epoch 86
# avg loss over epoch,
# Discriminator: 0.4871506839990616
# Generator: 1.2597824335098267
# epoch 86 finished in 1.277872085571289 s
#
#
# starting epoch 87
# avg loss over epoch,
# Discriminator: 0.47292307019233704
# Generator: 1.152549833059311
# epoch 87 finished in 1.2880609035491943 s
#
#
# starting epoch 88
# avg loss over epoch,
# Discriminator: 0.48745356500148773
# Generator: 1.0645443201065063
# epoch 88 finished in 1.2917795181274414 s
#
#
# starting epoch 89
# avg loss over epoch,
# Discriminator: 0.5052940398454666
# Generator: 1.1442741751670837
# epoch 89 finished in 1.2895376682281494 s
#
#
# starting epoch 90
# avg loss over epoch,
# Discriminator: 0.6194544732570648
# Generator: 1.0849560499191284
# epoch 90 finished in 1.281217098236084 s
#
#
# starting epoch 91
# avg loss over epoch,
# Discriminator: 0.5457060933113098
# Generator: 1.0465418696403503
# epoch 91 finished in 1.290604829788208 s
#
#
# starting epoch 92
# avg loss over epoch,
# Discriminator: 0.45388470590114594
# Generator: 1.0885705947875977
# epoch 92 finished in 1.2814867496490479 s
#
#
# starting epoch 93
# avg loss over epoch,
# Discriminator: 0.4519921988248825
# Generator: 1.2999898791313171
# epoch 93 finished in 1.2811222076416016 s
#
#
# starting epoch 94
# avg loss over epoch,
# Discriminator: 0.5484081208705902
# Generator: 1.1848892271518707
# epoch 94 finished in 1.2802019119262695 s
#
#
# starting epoch 95
# avg loss over epoch,
# Discriminator: 0.63393634557724
# Generator: 1.8704551458358765
# epoch 95 finished in 1.2865607738494873 s
#
#
# starting epoch 96
# avg loss over epoch,
# Discriminator: 0.5996892154216766
# Generator: 1.4661509990692139
# epoch 96 finished in 1.2761337757110596 s
#
#
# starting epoch 97
# avg loss over epoch,
# Discriminator: 0.5049951076507568
# Generator: 1.2403525710105896
# epoch 97 finished in 1.2821784019470215 s
#
#
# starting epoch 98
# avg loss over epoch,
# Discriminator: 0.5638673901557922
# Generator: 1.1140643656253815
# epoch 98 finished in 1.2786586284637451 s
#
#
# starting epoch 99
# avg loss over epoch,
# Discriminator: 0.5613116025924683
# Generator: 1.1031225323677063
# epoch 99 finished in 1.2840616703033447 s

# %%
plt.figure(figsize=(20,10))

plt.plot(gan_loss)
plt.plot(disc_loss)

plt.show()

# %%
from matplotlib import animation

ims = []
fig = plt.figure()
ax = fig.add_axes([0,0,1,1], frameon=False, aspect=1)
ax.set_xticks([]); ax.set_yticks([])

for train_ims in train_images:

    

    im_1 = plt.imshow(train_ims[0,:,:],vmin=0, vmax=1, animated=True) #add first image for test
    
    ims.append([im_1])
    #plt.pause(0.1) 

mp4_writer =  animation.writers['ffmpeg']
writer = mp4_writer(fps=24, metadata=dict(artist='Me'), bitrate=1800)


anim = animation.ArtistAnimation(fig,ims)
anim.save("test_gif_3.mp4", writer= writer)

# %%
fig,axs = plt.subplots(3,3)

print(axs.shape)

for i in range(axs.shape[0]):
    for j in range(axs.shape[1]):
        
        axs[i,j].set_xticks([])
        axs[i,j].set_yticks([])

images = []

#iterate ove images
for imgs in train_images:
    ims = [] 
    for i,img in enumerate(imgs):
        
        line = i%3
        col = int(i/3)
        ims.append(axs[line,col].imshow(img[:,:],vmin=0, vmax=1, animated=True))
    
    images.append(ims)

mp4_writer =  animation.writers['ffmpeg']
writer = mp4_writer(fps=24, metadata=dict(artist='Me'), bitrate=1800)

anim = animation.ArtistAnimation(fig,images)
anim.save("train_grid.mp4", writer= writer)
# Out:
# (3, 3)
