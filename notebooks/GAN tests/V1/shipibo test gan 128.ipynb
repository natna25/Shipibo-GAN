# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

os.chdir("/content/drive/My Drive/GAN/Shipibo GAN/")
# !ls
# Out:
# Mounted at /content/drive
# 'Copy of Shipibo gan test 1.ipynb'   test_gif_128.mp4
#  preproc			     test_gif_2.mp4
# 'Shipibo gan test 1.ipynb'	     test_gif_3.mp4
# 'shipibo test gan 128.ipynb'	     train_grid.mp4
# 'shipibo test gan 32.ipynb'

# %%
from keras.preprocessing.image import load_img,img_to_array
from PIL import Image

def load_images(path,size=128):
    """ loads images into a numpy array and returns them
    """
    img_paths = [path + f  for f in os.listdir(path)]
    print(len(img_paths))
    dataset_shape = (len(img_paths),size,size,3)

    data = np.ndarray(shape=dataset_shape)

    for i,f in enumerate(os.listdir(path)):
        im = Image.open(path + f)
        
        im = np.array(im)
        
        if i % 20 == 0:
            print("loaded ", i,"images" )

        data[i] = im.astype(int)
        

    print(data.shape)

    return data
data = load_images("preproc/128/")
# Out:
# Using TensorFlow backend.
# 288
# loaded  0 images
# loaded  20 images
# loaded  40 images
# loaded  60 images
# loaded  80 images
# loaded  100 images
# loaded  120 images
# loaded  140 images
# loaded  160 images
# loaded  180 images
# loaded  200 images
# loaded  220 images
# loaded  240 images
# loaded  260 images
# loaded  280 images
# (288, 128, 128, 3)

# %%
#warning, only run this once or else load the data all over again
data = (data - 127.5) / 127.5

# %%
test = (data[0] + 1) / 2.0
plt.imshow(test)

# %%
def generate_real_samples(data,n_samples):
    
    rand_indexes = np.random.randint(0,data.shape[0],n_samples)
    
    X_samples = data[rand_indexes]
    y_samples = np.ones((n_samples,1))
    
    return X_samples,y_samples

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Conv2D
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers import LeakyReLU
from keras.optimizers import Adam

def make_discriminator(input_shape=(128,128,3)):
    
    model = Sequential()
    #normal layer
    model.add(Conv2D(64,(3,3),padding="same",input_shape=input_shape))
    model.add(LeakyReLU(alpha=0.2))
    
    #downsample
    model.add(Conv2D(128,(3,3),strides=(2,2),padding="same"))
    
    model.add(LeakyReLU(alpha=0.2))
    
    #downsample
    model.add(Conv2D(128,(3,3),strides=(2,2),padding="same"))
    model.add(LeakyReLU(alpha=0.2))
    
    #downsample
    model.add(Conv2D(256,(3,3),strides=(2,2),padding="same"))
    model.add(LeakyReLU(alpha=0.2))

    #keep this comented for 32x32 version
    #downsample
    model.add(Conv2D(256,(3,3),strides=(2,2),padding="same"))
    model.add(LeakyReLU(alpha=0.2))
    
    #downsample
    model.add(Conv2D(256,(3,3),strides=(2,2),padding="same"))
    model.add(LeakyReLU(alpha=0.2))
    

    #flatten then pass through fully connected layer
    model.add(Flatten())
    model.add(Dropout(0.4))
    model.add(Dense(1,activation="sigmoid"))
    
    opt = Adam(lr=0.0002,beta_1=0.5)
    
    model.compile(loss="binary_crossentropy",optimizer=opt,metrics=["accuracy"])
    
    return model

# %%
from keras.layers import Reshape
from keras.layers import Conv2DTranspose

# define the standalone generator model
def make_generator(latent_dim=100):
    model = Sequential()
    # foundation for 4x4 image
    n_nodes = 256 * 4 * 4
    model.add(Dense(n_nodes, input_dim=latent_dim))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Reshape((4, 4, 256)))
    # upsample to 8x8
    model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    # upsample to 16x16
    model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    # upsample to 32x32
    model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    
    #upsample to 64x64
    model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    
    #upsample to 128x128
    model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    
    # output layer
    model.add(Conv2D(3, (3,3), activation='tanh', padding='same'))
    return model

# %%
def generate_latent_points(n_samples,latent_dim=100):
    
    latent_points = np.random.randn(latent_dim*n_samples)
    
    latent_points = latent_points.reshape((n_samples,latent_dim))
    
    return latent_points

def generate_fake_samples(generator,n_samples,latent_dim=100):
    
    #first generate latent points, then pass them to the generator
    
    latent_points = generate_latent_points(n_samples,latent_dim)
    
    X_fake = generator.predict(latent_points)
    
    y_fake = np.zeros((n_samples,1))
    
    return X_fake,y_fake

# %%
def make_gan(discriminator,generator):
    
    model = Sequential()
    
    discriminator.trainable = False
    
    model.add(generator)
    
    model.add(discriminator)
    
    opt = Adam(lr=0.0002, beta_1=0.5)
    model.compile(loss="binary_crossentropy",optimizer=opt)
    
    return model

# %%
import time

def train_gan(data,gan,discriminator,generator,n_epochs=200,batch_size=64):
    batch_per_epoch = int(data.shape[0] / batch_size)
    half_batch = int(batch_size / 2)
    
    n_points = 9
    fixed_latent_points = generate_latent_points(n_points)
    train_images = []
    
    gan_loss = []
    disc_loss = []
    
    
    for epoch in range(n_epochs):
        print("starting epoch",epoch)
        start_time = time.time()
        
        avg_epoch_disc_loss= []
        avg_epoch_gen_loss = []

        for batch in range(batch_per_epoch):
            
            #train the discriminator
            X_real,y_real = generate_real_samples(data,half_batch)
            X_fake,y_fake = generate_fake_samples(generator,half_batch)
            
            X,y = np.vstack((X_real,X_fake)) , np.vstack((y_real, y_fake))
            
            d_loss, _ = discriminator.train_on_batch(X,y)
            
            #train the generator (through the gan model by using the discriminator's error)
            lat_points = generate_latent_points(batch_size)
            y_gan = np.ones((batch_size,1))
            
            g_loss = gan.train_on_batch(lat_points,y_gan)
            
            
            #paint some pictures
            if epoch % 1 == 0:
                imgs = generator.predict(fixed_latent_points)

                #renormalize images for easy printing
                imgs = (imgs + 1) / 2.0
                train_images.append(imgs)
                
                #add loss to storage for graphing
                
                gan_loss.append(g_loss)
                disc_loss.append(d_loss)
            
            avg_epoch_disc_loss.append(d_loss)
            avg_epoch_gen_loss.append(g_loss)

        stop_time = time.time()
        print("avg loss over epoch, \nDiscriminator:" ,sum(avg_epoch_disc_loss)/len(avg_epoch_disc_loss),"\nGenerator:",sum(avg_epoch_gen_loss)/len(avg_epoch_gen_loss))
        print("epoch",epoch,"finished in",stop_time - start_time,"s\n\n")
            
            
    return train_images,gan_loss,disc_loss


reset_train = True

if reset_train:    
    discriminator = make_discriminator()
    generator = make_generator()

    gan = make_gan(discriminator,generator)



train_images,gan_loss,disc_loss = train_gan(data,gan,discriminator,generator,n_epochs=500)
# Out:
# starting epoch 0
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# avg loss over epoch,
# Discriminator: 0.6298751831054688
# Generator: 0.6927463114261627
# epoch 0 finished in 12.555914402008057 s
#
#
# starting epoch 1
# avg loss over epoch,
# Discriminator: 0.4177316352725029
# Generator: 0.660119503736496
# epoch 1 finished in 4.881483316421509 s
#
#
# starting epoch 2
# avg loss over epoch,
# Discriminator: 0.4924160912632942
# Generator: 0.7266216278076172
# epoch 2 finished in 4.869985103607178 s
#
#
# starting epoch 3
# avg loss over epoch,
# Discriminator: 0.402814045548439
# Generator: 0.9401772022247314
# epoch 3 finished in 4.874769687652588 s
#
#
# starting epoch 4
# avg loss over epoch,
# Discriminator: 0.3219870254397392
# Generator: 0.83513443171978
# epoch 4 finished in 4.872699737548828 s
#
#
# starting epoch 5
# avg loss over epoch,
# Discriminator: 0.27797622978687286
# Generator: 0.932064026594162
# epoch 5 finished in 4.890040397644043 s
#
#
# starting epoch 6
# avg loss over epoch,
# Discriminator: 0.19824708625674248
# Generator: 1.3776869773864746
# epoch 6 finished in 4.888840436935425 s
#
#
# starting epoch 7
# avg loss over epoch,
# Discriminator: 0.22367229498922825
# Generator: 2.741784989833832
# epoch 7 finished in 4.855315446853638 s
#
#
# starting epoch 8
# avg loss over epoch,
# Discriminator: 0.3997700549662113
# Generator: 5.089946866035461
# epoch 8 finished in 4.876207590103149 s
#
#
# starting epoch 9
# avg loss over epoch,
# Discriminator: 0.3086787164211273
# Generator: 4.485406398773193
# epoch 9 finished in 4.873763799667358 s
#
#
# starting epoch 10
# avg loss over epoch,
# Discriminator: 0.03316666558384895
# Generator: 4.69534569978714
# epoch 10 finished in 4.863144159317017 s
#
#
# starting epoch 11
# avg loss over epoch,
# Discriminator: 0.5537654161453247
# Generator: 1.1615625023841858
# epoch 11 finished in 4.875824928283691 s
#
#
# starting epoch 12
# avg loss over epoch,
# Discriminator: 0.3035603314638138
# Generator: 1.9686256647109985
# epoch 12 finished in 4.878174066543579 s
#
#
# starting epoch 13
# avg loss over epoch,
# Discriminator: 0.35376111045479774
# Generator: 2.9468925446271896
# epoch 13 finished in 4.868322372436523 s
#
#
# starting epoch 14
# avg loss over epoch,
# Discriminator: 0.5314712971448898
# Generator: 1.0710946023464203
# epoch 14 finished in 4.868084192276001 s
#
#
# starting epoch 15
# avg loss over epoch,
# Discriminator: 0.25238898396492004
# Generator: 8.978749990463257
# epoch 15 finished in 4.864840984344482 s
#
#
# starting epoch 16
# avg loss over epoch,
# Discriminator: 1.0127404108643532
# Generator: 0.8689225967973471
# epoch 16 finished in 4.870082855224609 s
#
#
# starting epoch 17
# avg loss over epoch,
# Discriminator: 0.4600408524274826
# Generator: 1.087611824274063
# epoch 17 finished in 4.861308813095093 s
#
#
# starting epoch 18
# avg loss over epoch,
# Discriminator: 0.3062325567007065
# Generator: 1.3794384002685547
# epoch 18 finished in 4.880773067474365 s
#
#
# starting epoch 19
# avg loss over epoch,
# Discriminator: 0.21738301217556
# Generator: 1.7310064733028412
# epoch 19 finished in 4.880095720291138 s
#
#
# starting epoch 20
# avg loss over epoch,
# Discriminator: 0.2958497405052185
# Generator: 2.287581145763397
# epoch 20 finished in 4.875974416732788 s
#
#
# starting epoch 21
# avg loss over epoch,
# Discriminator: 1.032702550292015
# Generator: 2.554196149110794
# epoch 21 finished in 4.8703248500823975 s
#
#
# starting epoch 22
# avg loss over epoch,
# Discriminator: 0.23166469857096672
# Generator: 3.0679140090942383
# epoch 22 finished in 4.8718061447143555 s
#
#
# starting epoch 23
# avg loss over epoch,
# Discriminator: 0.17740769684314728
# Generator: 3.6493722200393677
# epoch 23 finished in 4.878138065338135 s
#
#
# starting epoch 24
# avg loss over epoch,
# Discriminator: 0.2717990167438984
# Generator: 3.667044162750244
# epoch 24 finished in 4.866425514221191 s
#
#
# starting epoch 25
# avg loss over epoch,
# Discriminator: 0.5142416581511497
# Generator: 3.2568278908729553
# epoch 25 finished in 4.87539529800415 s
#
#
# starting epoch 26
# avg loss over epoch,
# Discriminator: 0.4986424148082733
# Generator: 2.214998185634613
# epoch 26 finished in 4.891425848007202 s
#
#
# starting epoch 27
# avg loss over epoch,
# Discriminator: 0.155146736651659
# Generator: 3.3634458780288696
# epoch 27 finished in 4.889725208282471 s
#
#
# starting epoch 28
# avg loss over epoch,
# Discriminator: 0.0859963046386838
# Generator: 4.433628693223
# epoch 28 finished in 4.888551235198975 s
#
#
# starting epoch 29
# avg loss over epoch,
# Discriminator: 0.4165537692606449
# Generator: 5.321674942970276
# epoch 29 finished in 4.878828048706055 s
#
#
# starting epoch 30
# avg loss over epoch,
# Discriminator: 0.40874792635440826
# Generator: 3.637519896030426
# epoch 30 finished in 4.864252805709839 s
#
#
# starting epoch 31
# avg loss over epoch,
# Discriminator: 0.2075267881155014
# Generator: 2.645636737346649
# epoch 31 finished in 4.884677410125732 s
#
#
# starting epoch 32
# avg loss over epoch,
# Discriminator: 0.21963633596897125
# Generator: 3.020254075527191
# epoch 32 finished in 4.8735363483428955 s
#
#
# starting epoch 33
# avg loss over epoch,
# Discriminator: 0.42654310911893845
# Generator: 4.261208117008209
# epoch 33 finished in 4.883335590362549 s
#
#
# starting epoch 34
# avg loss over epoch,
# Discriminator: 0.29887062311172485
# Generator: 2.7770586013793945
# epoch 34 finished in 4.885186433792114 s
#
#
# starting epoch 35
# avg loss over epoch,
# Discriminator: 0.12851796485483646
# Generator: 3.104650557041168
# epoch 35 finished in 4.868454933166504 s
#
#
# starting epoch 36
# avg loss over epoch,
# Discriminator: 0.20176914148032665
# Generator: 3.7752970457077026
# epoch 36 finished in 4.87158203125 s
#
#
# starting epoch 37
# avg loss over epoch,
# Discriminator: 0.31034138053655624
# Generator: 3.5935407876968384
# epoch 37 finished in 4.87067985534668 s
#
#
# starting epoch 38
# avg loss over epoch,
# Discriminator: 0.19369815289974213
# Generator: 4.75318831205368
# epoch 38 finished in 4.8930370807647705 s
#
#
# starting epoch 39
# avg loss over epoch,
# Discriminator: 0.635265652090311
# Generator: 5.020481765270233
# epoch 39 finished in 4.881330728530884 s
#
#
# starting epoch 40
# avg loss over epoch,
# Discriminator: 0.22859202697873116
# Generator: 3.677131414413452
# epoch 40 finished in 4.892215728759766 s
#
#
# starting epoch 41
# avg loss over epoch,
# Discriminator: 0.1641964241862297
# Generator: 3.8051706552505493
# epoch 41 finished in 4.882469654083252 s
#
#
# starting epoch 42
# avg loss over epoch,
# Discriminator: 0.0826890803873539
# Generator: 4.008929491043091
# epoch 42 finished in 4.874818801879883 s
#
#
# starting epoch 43
# avg loss over epoch,
# Discriminator: 0.17677326127886772
# Generator: 7.909896969795227
# epoch 43 finished in 4.886725664138794 s
#
#
# starting epoch 44
# avg loss over epoch,
# Discriminator: 0.5570671558380127
# Generator: 7.756155729293823
# epoch 44 finished in 4.883729934692383 s
#
#
# starting epoch 45
# avg loss over epoch,
# Discriminator: 0.29478442668914795
# Generator: 4.424047887325287
# epoch 45 finished in 4.866123914718628 s
#
#
# starting epoch 46
# avg loss over epoch,
# Discriminator: 0.29123056679964066
# Generator: 3.688517153263092
# epoch 46 finished in 4.879392862319946 s
#
#
# starting epoch 47
# avg loss over epoch,
# Discriminator: 0.16027171164751053
# Generator: 3.963785171508789
# epoch 47 finished in 4.886643886566162 s
#
#
# starting epoch 48
# avg loss over epoch,
# Discriminator: 0.15757295116782188
# Generator: 4.845929861068726
# epoch 48 finished in 4.895752191543579 s
#
#
# starting epoch 49
# avg loss over epoch,
# Discriminator: 1.0127502046525478
# Generator: 7.375356912612915
# epoch 49 finished in 4.8736748695373535 s
#
#
# starting epoch 50
# avg loss over epoch,
# Discriminator: 0.5295065864920616
# Generator: 1.5865247547626495
# epoch 50 finished in 4.870968818664551 s
#
#
# starting epoch 51
# avg loss over epoch,
# Discriminator: 0.20434732362627983
# Generator: 3.348802626132965
# epoch 51 finished in 4.876283407211304 s
#
#
# starting epoch 52
# avg loss over epoch,
# Discriminator: 0.34623562544584274
# Generator: 3.3882492184638977
# epoch 52 finished in 4.883967161178589 s
#
#
# starting epoch 53
# avg loss over epoch,
# Discriminator: 0.5603853985667229
# Generator: 2.019191861152649
# epoch 53 finished in 4.890460014343262 s
#
#
# starting epoch 54
# avg loss over epoch,
# Discriminator: 0.47410721331834793
# Generator: 2.555179178714752
# epoch 54 finished in 4.878080368041992 s
#
#
# starting epoch 55
# avg loss over epoch,
# Discriminator: 0.3877340704202652
# Generator: 4.369018077850342
# epoch 55 finished in 4.8821985721588135 s
#
#
# starting epoch 56
# avg loss over epoch,
# Discriminator: 0.14388041570782661
# Generator: 5.980156898498535
# epoch 56 finished in 4.864333391189575 s
#
#
# starting epoch 57
# avg loss over epoch,
# Discriminator: 0.36915862187743187
# Generator: 5.696940660476685
# epoch 57 finished in 4.870917320251465 s
#
#
# starting epoch 58
# avg loss over epoch,
# Discriminator: 0.8050959631800652
# Generator: 2.7072722911834717
# epoch 58 finished in 4.873537063598633 s
#
#
# starting epoch 59
# avg loss over epoch,
# Discriminator: 0.30750784277915955
# Generator: 3.941057562828064
# epoch 59 finished in 4.904515266418457 s
#
#
# starting epoch 60
# avg loss over epoch,
# Discriminator: 0.29912666231393814
# Generator: 2.5101794600486755
# epoch 60 finished in 4.873519420623779 s
#
#
# starting epoch 61
# avg loss over epoch,
# Discriminator: 0.22029845044016838
# Generator: 2.440758466720581
# epoch 61 finished in 4.885079383850098 s
#
#
# starting epoch 62
# avg loss over epoch,
# Discriminator: 0.301685206592083
# Generator: 2.5483872294425964
# epoch 62 finished in 4.865118026733398 s
#
#
# starting epoch 63
# avg loss over epoch,
# Discriminator: 0.19078382849693298
# Generator: 2.7455813884735107
# epoch 63 finished in 4.875967502593994 s
#
#
# starting epoch 64
# avg loss over epoch,
# Discriminator: 0.1696223597973585
# Generator: 3.3710079193115234
# epoch 64 finished in 4.884310007095337 s
#
#
# starting epoch 65
# avg loss over epoch,
# Discriminator: 0.13086505606770515
# Generator: 3.9184974431991577
# epoch 65 finished in 4.899608850479126 s
#
#
# starting epoch 66
# avg loss over epoch,
# Discriminator: 0.21021587774157524
# Generator: 4.3058465123176575
# epoch 66 finished in 4.865329265594482 s
#
#
# starting epoch 67
# avg loss over epoch,
# Discriminator: 0.14518512412905693
# Generator: 4.31965446472168
# epoch 67 finished in 4.8905348777771 s
#
#
# starting epoch 68
# avg loss over epoch,
# Discriminator: 0.09508191980421543
# Generator: 4.558444499969482
# epoch 68 finished in 4.885900974273682 s
#
#
# starting epoch 69
# avg loss over epoch,
# Discriminator: 0.06942152790725231
# Generator: 4.543560147285461
# epoch 69 finished in 4.889176845550537 s
#
#
# starting epoch 70
# avg loss over epoch,
# Discriminator: 0.41686868853867054
# Generator: 7.400751709938049
# epoch 70 finished in 4.874281883239746 s
#
#
# starting epoch 71
# avg loss over epoch,
# Discriminator: 0.09641148708760738
# Generator: 4.6100189089775085
# epoch 71 finished in 4.872830390930176 s
#
#
# starting epoch 72
# avg loss over epoch,
# Discriminator: 0.51137475669384
# Generator: 13.756866216659546
# epoch 72 finished in 4.803036451339722 s
#
#
# starting epoch 73
# avg loss over epoch,
# Discriminator: 0.06435048393905163
# Generator: 3.798081159591675
# epoch 73 finished in 4.893198490142822 s
#
#
# starting epoch 74
# avg loss over epoch,
# Discriminator: 0.06433472875505686
# Generator: 4.011718690395355
# epoch 74 finished in 4.885754346847534 s
#
#
# starting epoch 75
# avg loss over epoch,
# Discriminator: 0.08580206241458654
# Generator: 3.67590993642807
# epoch 75 finished in 4.881289005279541 s
#
#
# starting epoch 76
# avg loss over epoch,
# Discriminator: 0.11820738576352596
# Generator: 4.157144784927368
# epoch 76 finished in 4.882516622543335 s
#
#
# starting epoch 77
# avg loss over epoch,
# Discriminator: 0.34811147302389145
# Generator: 4.148855447769165
# epoch 77 finished in 4.883357048034668 s
#
#
# starting epoch 78
# avg loss over epoch,
# Discriminator: 0.19199080392718315
# Generator: 4.342150449752808
# epoch 78 finished in 4.879503965377808 s
#
#
# starting epoch 79
# avg loss over epoch,
# Discriminator: 0.23263896629214287
# Generator: 3.946238100528717
# epoch 79 finished in 4.8802170753479 s
#
#
# starting epoch 80
# avg loss over epoch,
# Discriminator: 0.370010182261467
# Generator: 5.137366771697998
# epoch 80 finished in 4.8853795528411865 s
#
#
# starting epoch 81
# avg loss over epoch,
# Discriminator: 0.6383313834667206
# Generator: 5.744082152843475
# epoch 81 finished in 4.870880126953125 s
#
#
# starting epoch 82
# avg loss over epoch,
# Discriminator: 0.2517045885324478
# Generator: 3.480684518814087
# epoch 82 finished in 4.860849142074585 s
#
#
# starting epoch 83
# avg loss over epoch,
# Discriminator: 0.29516520351171494
# Generator: 2.9816707968711853
# epoch 83 finished in 4.875622034072876 s
#
#
# starting epoch 84
# avg loss over epoch,
# Discriminator: 0.2794963866472244
# Generator: 2.6043718457221985
# epoch 84 finished in 4.860800743103027 s
#
#
# starting epoch 85
# avg loss over epoch,
# Discriminator: 0.2647646702826023
# Generator: 3.247083067893982
# epoch 85 finished in 4.881003379821777 s
#
#
# starting epoch 86
# avg loss over epoch,
# Discriminator: 0.20341981947422028
# Generator: 3.7522497177124023
# epoch 86 finished in 4.878061532974243 s
#
#
# starting epoch 87
# avg loss over epoch,
# Discriminator: 0.3790670298039913
# Generator: 5.22620964050293
# epoch 87 finished in 4.877968788146973 s
#
#
# starting epoch 88
# avg loss over epoch,
# Discriminator: 0.4043341279029846
# Generator: 5.917222857475281
# epoch 88 finished in 4.879120826721191 s
#
#
# starting epoch 89
# avg loss over epoch,
# Discriminator: 0.7578225806355476
# Generator: 3.948346197605133
# epoch 89 finished in 4.885380744934082 s
#
#
# starting epoch 90
# avg loss over epoch,
# Discriminator: 0.3562747538089752
# Generator: 2.4599708020687103
# epoch 90 finished in 4.87666916847229 s
#
#
# starting epoch 91
# avg loss over epoch,
# Discriminator: 0.13685715198516846
# Generator: 3.260338842868805
# epoch 91 finished in 4.88122034072876 s
#
#
# starting epoch 92
# avg loss over epoch,
# Discriminator: 0.22153502702713013
# Generator: 3.9519512057304382
# epoch 92 finished in 4.896061420440674 s
#
#
# starting epoch 93
# avg loss over epoch,
# Discriminator: 0.10358350165188313
# Generator: 3.609156012535095
# epoch 93 finished in 4.883067607879639 s
#
#
# starting epoch 94
# avg loss over epoch,
# Discriminator: 0.08727861382067204
# Generator: 3.8667463064193726
# epoch 94 finished in 4.891186475753784 s
#
#
# starting epoch 95
# avg loss over epoch,
# Discriminator: 0.13694414123892784
# Generator: 4.5087854862213135
# epoch 95 finished in 4.893154144287109 s
#
#
# starting epoch 96
# avg loss over epoch,
# Discriminator: 0.0840185210108757
# Generator: 5.704025626182556
# epoch 96 finished in 4.883186340332031 s
#
#
# starting epoch 97
# avg loss over epoch,
# Discriminator: 0.0899417344480753
# Generator: 5.810520887374878
# epoch 97 finished in 4.889699697494507 s
#
#
# starting epoch 98
# avg loss over epoch,
# Discriminator: 0.1716114766895771
# Generator: 6.774707317352295
# epoch 98 finished in 4.887583017349243 s
#
#
# starting epoch 99
# avg loss over epoch,
# Discriminator: 0.29535768553614616
# Generator: 3.514414131641388
# epoch 99 finished in 4.889434099197388 s
#
#
# starting epoch 100
# avg loss over epoch,
# Discriminator: 0.08200062159448862
# Generator: 7.021541953086853
# epoch 100 finished in 4.882135629653931 s
#
#
# starting epoch 101
# avg loss over epoch,
# Discriminator: 0.15571023151278496
# Generator: 4.756628394126892
# epoch 101 finished in 4.8850486278533936 s
#
#
# starting epoch 102
# avg loss over epoch,
# Discriminator: 0.08978683687746525
# Generator: 4.249589681625366
# epoch 102 finished in 4.884326934814453 s
#
#
# starting epoch 103
# avg loss over epoch,
# Discriminator: 0.1567443460226059
# Generator: 4.716896653175354
# epoch 103 finished in 4.890847206115723 s
#
#
# starting epoch 104
# avg loss over epoch,
# Discriminator: 0.17065003514289856
# Generator: 4.971027731895447
# epoch 104 finished in 4.888224124908447 s
#
#
# starting epoch 105
# avg loss over epoch,
# Discriminator: 0.13612626120448112
# Generator: 4.702643156051636
# epoch 105 finished in 4.884687900543213 s
#
#
# starting epoch 106
# avg loss over epoch,
# Discriminator: 0.11580944806337357
# Generator: 4.7792888879776
# epoch 106 finished in 4.867888450622559 s
#
#
# starting epoch 107
# avg loss over epoch,
# Discriminator: 0.14783416874706745
# Generator: 5.560410022735596
# epoch 107 finished in 4.879699945449829 s
#
#
# starting epoch 108
# avg loss over epoch,
# Discriminator: 0.4381977468729019
# Generator: 10.046912431716919
# epoch 108 finished in 4.8816819190979 s
#
#
# starting epoch 109
# avg loss over epoch,
# Discriminator: 0.36205240339040756
# Generator: 8.648168563842773
# epoch 109 finished in 4.879037618637085 s
#
#
# starting epoch 110
# avg loss over epoch,
# Discriminator: 0.08954321243800223
# Generator: 3.902373433113098
# epoch 110 finished in 4.876360893249512 s
#
#
# starting epoch 111
# avg loss over epoch,
# Discriminator: 0.15276551991701126
# Generator: 3.2326281666755676
# epoch 111 finished in 4.862975120544434 s
#
#
# starting epoch 112
# avg loss over epoch,
# Discriminator: 0.09640720393508673
# Generator: 3.875097632408142
# epoch 112 finished in 4.884413719177246 s
#
#
# starting epoch 113
# avg loss over epoch,
# Discriminator: 0.2651067189872265
# Generator: 4.487552523612976
# epoch 113 finished in 4.854243755340576 s
#
#
# starting epoch 114
# avg loss over epoch,
# Discriminator: 0.1890148352831602
# Generator: 6.737724184989929
# epoch 114 finished in 4.871108293533325 s
#
#
# starting epoch 115
# avg loss over epoch,
# Discriminator: 0.35812645964324474
# Generator: 6.545600056648254
# epoch 115 finished in 4.882129907608032 s
#
#
# starting epoch 116
# avg loss over epoch,
# Discriminator: 0.21172316372394562
# Generator: 3.54741370677948
# epoch 116 finished in 4.879323244094849 s
#
#
# starting epoch 117
# avg loss over epoch,
# Discriminator: 0.10421131737530231
# Generator: 3.456297278404236
# epoch 117 finished in 4.884954452514648 s
#
#
# starting epoch 118
# avg loss over epoch,
# Discriminator: 0.07753844372928143
# Generator: 4.180564701557159
# epoch 118 finished in 4.870595455169678 s
#
#
# starting epoch 119
# avg loss over epoch,
# Discriminator: 0.2856061980128288
# Generator: 7.342456817626953
# epoch 119 finished in 4.8778557777404785 s
#
#
# starting epoch 120
# avg loss over epoch,
# Discriminator: 0.8610780462622643
# Generator: 2.5852074176073074
# epoch 120 finished in 4.871194362640381 s
#
#
# starting epoch 121
# avg loss over epoch,
# Discriminator: 0.33287882059812546
# Generator: 1.8455467224121094
# epoch 121 finished in 4.897087812423706 s
#
#
# starting epoch 122
# avg loss over epoch,
# Discriminator: 0.36179105192422867
# Generator: 1.6090939044952393
# epoch 122 finished in 4.890593528747559 s
#
#
# starting epoch 123
# avg loss over epoch,
# Discriminator: 0.24253595247864723
# Generator: 1.9997579157352448
# epoch 123 finished in 4.8746514320373535 s
#
#
# starting epoch 124
# avg loss over epoch,
# Discriminator: 0.18248369544744492
# Generator: 2.421937584877014
# epoch 124 finished in 4.870367527008057 s
#
#
# starting epoch 125
# avg loss over epoch,
# Discriminator: 0.1574157513678074
# Generator: 3.923564076423645
# epoch 125 finished in 4.8737616539001465 s
#
#
# starting epoch 126
# avg loss over epoch,
# Discriminator: 0.12844265438616276
# Generator: 3.692216455936432
# epoch 126 finished in 4.870651483535767 s
#
#
# starting epoch 127
# avg loss over epoch,
# Discriminator: 0.06069266516715288
# Generator: 3.870568871498108
# epoch 127 finished in 4.871671915054321 s
#
#
# starting epoch 128
# avg loss over epoch,
# Discriminator: 0.0759652592241764
# Generator: 3.5812323093414307
# epoch 128 finished in 4.882584571838379 s
#
#
# starting epoch 129
# avg loss over epoch,
# Discriminator: 0.4967682808637619
# Generator: 4.3821858167648315
# epoch 129 finished in 4.865723609924316 s
#
#
# starting epoch 130
# avg loss over epoch,
# Discriminator: 0.6842942833900452
# Generator: 5.785920977592468
# epoch 130 finished in 4.8789989948272705 s
#
#
# starting epoch 131
# avg loss over epoch,
# Discriminator: 0.3287339061498642
# Generator: 3.202428460121155
# epoch 131 finished in 4.872783660888672 s
#
#
# starting epoch 132
# avg loss over epoch,
# Discriminator: 0.24254271015524864
# Generator: 2.9101210832595825
# epoch 132 finished in 4.886516571044922 s
#
#
# starting epoch 133
# avg loss over epoch,
# Discriminator: 0.2741597592830658
# Generator: 4.0479631423950195
# epoch 133 finished in 4.884124279022217 s
#
#
# starting epoch 134
# avg loss over epoch,
# Discriminator: 0.15631980821490288
# Generator: 5.117159605026245
# epoch 134 finished in 4.89030122756958 s
#
#
# starting epoch 135
# avg loss over epoch,
# Discriminator: 0.11310097575187683
# Generator: 3.7585907578468323
# epoch 135 finished in 4.882020950317383 s
#
#
# starting epoch 136
# avg loss over epoch,
# Discriminator: 0.20353280752897263
# Generator: 2.949524998664856
# epoch 136 finished in 4.888091087341309 s
#
#
# starting epoch 137
# avg loss over epoch,
# Discriminator: 0.12535508908331394
# Generator: 3.4502300024032593
# epoch 137 finished in 4.87703275680542 s
#
#
# starting epoch 138
# avg loss over epoch,
# Discriminator: 0.4918399900197983
# Generator: 5.7627469301223755
# epoch 138 finished in 4.876368761062622 s
#
#
# starting epoch 139
# avg loss over epoch,
# Discriminator: 0.226467065513134
# Generator: 3.0337077975273132
# epoch 139 finished in 4.873719930648804 s
#
#
# starting epoch 140
# avg loss over epoch,
# Discriminator: 0.31558358669281006
# Generator: 3.642106592655182
# epoch 140 finished in 4.889446973800659 s
#
#
# starting epoch 141
# avg loss over epoch,
# Discriminator: 0.3437221422791481
# Generator: 4.09370094537735
# epoch 141 finished in 4.882108926773071 s
#
#
# starting epoch 142
# avg loss over epoch,
# Discriminator: 0.08049510978162289
# Generator: 3.038678765296936
# epoch 142 finished in 4.8915863037109375 s
#
#
# starting epoch 143
# avg loss over epoch,
# Discriminator: 0.08549545332789421
# Generator: 3.419755697250366
# epoch 143 finished in 4.868254899978638 s
#
#
# starting epoch 144
# avg loss over epoch,
# Discriminator: 0.36602063477039337
# Generator: 3.4653585255146027
# epoch 144 finished in 4.883528709411621 s
#
#
# starting epoch 145
# avg loss over epoch,
# Discriminator: 0.4041324146091938
# Generator: 2.95348659157753
# epoch 145 finished in 4.872442722320557 s
#
#
# starting epoch 146
# avg loss over epoch,
# Discriminator: 0.24630258977413177
# Generator: 2.8169129490852356
# epoch 146 finished in 4.8869898319244385 s
#
#
# starting epoch 147
# avg loss over epoch,
# Discriminator: 0.35615192353725433
# Generator: 3.888567805290222
# epoch 147 finished in 4.883333206176758 s
#
#
# starting epoch 148
# avg loss over epoch,
# Discriminator: 0.38825028389692307
# Generator: 3.9799821972846985
# epoch 148 finished in 4.88579249382019 s
#
#
# starting epoch 149
# avg loss over epoch,
# Discriminator: 0.17134100012481213
# Generator: 4.721866130828857
# epoch 149 finished in 4.86957573890686 s
#
#
# starting epoch 150
# avg loss over epoch,
# Discriminator: 0.24054671823978424
# Generator: 4.855221807956696
# epoch 150 finished in 4.887997627258301 s
#
#
# starting epoch 151
# avg loss over epoch,
# Discriminator: 0.3732951655983925
# Generator: 3.6951801776885986
# epoch 151 finished in 4.888231039047241 s
#
#
# starting epoch 152
# avg loss over epoch,
# Discriminator: 0.2283897064626217
# Generator: 3.930555582046509
# epoch 152 finished in 4.885985374450684 s
#
#
# starting epoch 153
# avg loss over epoch,
# Discriminator: 0.18359588831663132
# Generator: 3.1254113912582397
# epoch 153 finished in 4.8762054443359375 s
#
#
# starting epoch 154
# avg loss over epoch,
# Discriminator: 0.13633464090526104
# Generator: 2.925817370414734
# epoch 154 finished in 4.899085998535156 s
#
#
# starting epoch 155
# avg loss over epoch,
# Discriminator: 0.17193179577589035
# Generator: 4.223956823348999
# epoch 155 finished in 4.873807907104492 s
#
#
# starting epoch 156
# avg loss over epoch,
# Discriminator: 0.237605232745409
# Generator: 4.922699451446533
# epoch 156 finished in 4.873998403549194 s
#
#
# starting epoch 157
# avg loss over epoch,
# Discriminator: 0.24786999449133873
# Generator: 3.3977117016911507
# epoch 157 finished in 4.881170034408569 s
#
#
# starting epoch 158
# avg loss over epoch,
# Discriminator: 0.6108522117137909
# Generator: 5.402467727661133
# epoch 158 finished in 4.878815174102783 s
#
#
# starting epoch 159
# avg loss over epoch,
# Discriminator: 0.17901085875928402
# Generator: 2.2290806770324707
# epoch 159 finished in 4.8746178150177 s
#
#
# starting epoch 160
# avg loss over epoch,
# Discriminator: 0.20700720325112343
# Generator: 2.57374507188797
# epoch 160 finished in 4.895121097564697 s
#
#
# starting epoch 161
# avg loss over epoch,
# Discriminator: 0.2936561219394207
# Generator: 2.7656410932540894
# epoch 161 finished in 4.8782854080200195 s
#
#
# starting epoch 162
# avg loss over epoch,
# Discriminator: 0.3240875229239464
# Generator: 2.9858789443969727
# epoch 162 finished in 4.859441041946411 s
#
#
# starting epoch 163
# avg loss over epoch,
# Discriminator: 0.2508702501654625
# Generator: 2.9849568605422974
# epoch 163 finished in 4.886906385421753 s
#
#
# starting epoch 164
# avg loss over epoch,
# Discriminator: 0.20602459087967873
# Generator: 2.9732006788253784
# epoch 164 finished in 4.880722284317017 s
#
#
# starting epoch 165
# avg loss over epoch,
# Discriminator: 0.23185206949710846
# Generator: 3.868339240550995
# epoch 165 finished in 4.880893707275391 s
#
#
# starting epoch 166
# avg loss over epoch,
# Discriminator: 0.3302266299724579
# Generator: 5.093679130077362
# epoch 166 finished in 4.881914138793945 s
#
#
# starting epoch 167
# avg loss over epoch,
# Discriminator: 0.3416624292731285
# Generator: 3.8689433336257935
# epoch 167 finished in 4.878282308578491 s
#
#
# starting epoch 168
# avg loss over epoch,
# Discriminator: 0.1693727895617485
# Generator: 4.243706107139587
# epoch 168 finished in 4.880061864852905 s
#
#
# starting epoch 169
# avg loss over epoch,
# Discriminator: 0.18923202902078629
# Generator: 4.154439926147461
# epoch 169 finished in 4.8848655223846436 s
#
#
# starting epoch 170
# avg loss over epoch,
# Discriminator: 0.19520804286003113
# Generator: 3.6913720965385437
# epoch 170 finished in 4.873335838317871 s
#
#
# starting epoch 171
# avg loss over epoch,
# Discriminator: 0.2406649887561798
# Generator: 4.2935250997543335
# epoch 171 finished in 4.879662275314331 s
#
#
# starting epoch 172
# avg loss over epoch,
# Discriminator: 0.4478164613246918
# Generator: 4.1474864184856415
# epoch 172 finished in 4.8982837200164795 s
#
#
# starting epoch 173
# avg loss over epoch,
# Discriminator: 0.345828540623188
# Generator: 1.9331167340278625
# epoch 173 finished in 4.880244970321655 s
#
#
# starting epoch 174
# avg loss over epoch,
# Discriminator: 0.18073919415473938
# Generator: 2.44720995426178
# epoch 174 finished in 4.863404035568237 s
#
#
# starting epoch 175
# avg loss over epoch,
# Discriminator: 0.23188507556915283
# Generator: 2.387820839881897
# epoch 175 finished in 4.894955396652222 s
#
#
# starting epoch 176
# avg loss over epoch,
# Discriminator: 0.3479718342423439
# Generator: 3.2504037022590637
# epoch 176 finished in 4.88114070892334 s
#
#
# starting epoch 177
# avg loss over epoch,
# Discriminator: 0.3034534379839897
# Generator: 3.2447035908699036
# epoch 177 finished in 4.8721818923950195 s
#
#
# starting epoch 178
# avg loss over epoch,
# Discriminator: 0.2225416637957096
# Generator: 2.563732624053955
# epoch 178 finished in 4.880561351776123 s
#
#
# starting epoch 179
# avg loss over epoch,
# Discriminator: 0.22747701033949852
# Generator: 3.4314258098602295
# epoch 179 finished in 4.88056492805481 s
#
#
# starting epoch 180
# avg loss over epoch,
# Discriminator: 0.30235834047198296
# Generator: 4.399759411811829
# epoch 180 finished in 4.871551036834717 s
#
#
# starting epoch 181
# avg loss over epoch,
# Discriminator: 0.19728785939514637
# Generator: 3.2994731068611145
# epoch 181 finished in 4.8629021644592285 s
#
#
# starting epoch 182
# avg loss over epoch,
# Discriminator: 0.20201744139194489
# Generator: 3.101428508758545
# epoch 182 finished in 4.868908166885376 s
#
#
# starting epoch 183
# avg loss over epoch,
# Discriminator: 0.12775241769850254
# Generator: 3.319746255874634
# epoch 183 finished in 4.882295608520508 s
#
#
# starting epoch 184
# avg loss over epoch,
# Discriminator: 0.16304007545113564
# Generator: 4.026173830032349
# epoch 184 finished in 4.8850321769714355 s
#
#
# starting epoch 185
# avg loss over epoch,
# Discriminator: 0.23343873396515846
# Generator: 3.562242805957794
# epoch 185 finished in 4.87554407119751 s
#
#
# starting epoch 186
# avg loss over epoch,
# Discriminator: 0.24489977397024632
# Generator: 7.742568075656891
# epoch 186 finished in 4.882771968841553 s
#
#
# starting epoch 187
# avg loss over epoch,
# Discriminator: 0.17715194821357727
# Generator: 4.2132099866867065
# epoch 187 finished in 4.880263328552246 s
#
#
# starting epoch 188
# avg loss over epoch,
# Discriminator: 0.21947023272514343
# Generator: 2.914725124835968
# epoch 188 finished in 4.865783214569092 s
#
#
# starting epoch 189
# avg loss over epoch,
# Discriminator: 0.21998649835586548
# Generator: 3.146835505962372
# epoch 189 finished in 4.8752100467681885 s
#
#
# starting epoch 190
# avg loss over epoch,
# Discriminator: 0.24436408653855324
# Generator: 3.27728533744812
# epoch 190 finished in 4.877624988555908 s
#
#
# starting epoch 191
# avg loss over epoch,
# Discriminator: 0.2789827212691307
# Generator: 3.1784417033195496
# epoch 191 finished in 4.868623733520508 s
#
#
# starting epoch 192
# avg loss over epoch,
# Discriminator: 0.43616933934390545
# Generator: 7.08358108997345
# epoch 192 finished in 4.873804807662964 s
#
#
# starting epoch 193
# avg loss over epoch,
# Discriminator: 0.5430648922920227
# Generator: 3.4507634043693542
# epoch 193 finished in 4.881316900253296 s
#
#
# starting epoch 194
# avg loss over epoch,
# Discriminator: 0.1763273850083351
# Generator: 2.936679780483246
# epoch 194 finished in 4.8893141746521 s
#
#
# starting epoch 195
# avg loss over epoch,
# Discriminator: 0.28536106646060944
# Generator: 3.6294919848442078
# epoch 195 finished in 4.868405818939209 s
#
#
# starting epoch 196
# avg loss over epoch,
# Discriminator: 0.3508831411600113
# Generator: 3.8277933597564697
# epoch 196 finished in 4.885655403137207 s
#
#
# starting epoch 197
# avg loss over epoch,
# Discriminator: 0.23013737797737122
# Generator: 3.325577974319458
# epoch 197 finished in 4.9013965129852295 s
#
#
# starting epoch 198
# avg loss over epoch,
# Discriminator: 0.20245932042598724
# Generator: 2.990334391593933
# epoch 198 finished in 4.895487546920776 s
#
#
# starting epoch 199
# avg loss over epoch,
# Discriminator: 0.1647685393691063
# Generator: 2.671298921108246
# epoch 199 finished in 4.895787715911865 s
#
#
# starting epoch 200
# avg loss over epoch,
# Discriminator: 0.1718285232782364
# Generator: 2.7132442593574524
# epoch 200 finished in 4.899522066116333 s
#
#
# starting epoch 201
# avg loss over epoch,
# Discriminator: 0.27608463540673256
# Generator: 3.779769718647003
# epoch 201 finished in 4.889219522476196 s
#
#
# starting epoch 202
# avg loss over epoch,
# Discriminator: 0.48368433117866516
# Generator: 5.831199944019318
# epoch 202 finished in 4.895841360092163 s
#
#
# starting epoch 203
# avg loss over epoch,
# Discriminator: 0.6801444813609123
# Generator: 2.0112528800964355
# epoch 203 finished in 4.916598320007324 s
#
#
# starting epoch 204
# avg loss over epoch,
# Discriminator: 0.2747933939099312
# Generator: 2.4164304733276367
# epoch 204 finished in 4.919023752212524 s
#
#
# starting epoch 205
# avg loss over epoch,
# Discriminator: 0.32793354243040085
# Generator: 4.566417634487152
# epoch 205 finished in 4.90063738822937 s
#
#
# starting epoch 206
# avg loss over epoch,
# Discriminator: 0.18803126737475395
# Generator: 3.7622875571250916
# epoch 206 finished in 4.918210744857788 s
#
#
# starting epoch 207
# avg loss over epoch,
# Discriminator: 0.31195978447794914
# Generator: 2.9941352009773254
# epoch 207 finished in 4.904456853866577 s
#
#
# starting epoch 208
# avg loss over epoch,
# Discriminator: 0.42215635627508163
# Generator: 2.652728796005249
# epoch 208 finished in 4.911423444747925 s
#
#
# starting epoch 209
# avg loss over epoch,
# Discriminator: 0.3416193202137947
# Generator: 2.640457570552826
# epoch 209 finished in 4.914090156555176 s
#
#
# starting epoch 210
# avg loss over epoch,
# Discriminator: 0.31781454384326935
# Generator: 2.5962637662887573
# epoch 210 finished in 4.909545660018921 s
#
#
# starting epoch 211
# avg loss over epoch,
# Discriminator: 0.1872487347573042
# Generator: 3.9107754826545715
# epoch 211 finished in 4.908507823944092 s
#
#
# starting epoch 212
# avg loss over epoch,
# Discriminator: 0.12478668242692947
# Generator: 4.086962521076202
# epoch 212 finished in 4.922473669052124 s
#
#
# starting epoch 213
# avg loss over epoch,
# Discriminator: 0.15804293379187584
# Generator: 3.3722029328346252
# epoch 213 finished in 4.8951075077056885 s
#
#
# starting epoch 214
# avg loss over epoch,
# Discriminator: 0.3752644211053848
# Generator: 3.7813249826431274
# epoch 214 finished in 4.907011270523071 s
#
#
# starting epoch 215
# avg loss over epoch,
# Discriminator: 0.3858156315982342
# Generator: 3.7159462571144104
# epoch 215 finished in 4.909177541732788 s
#
#
# starting epoch 216
# avg loss over epoch,
# Discriminator: 0.34424691647291183
# Generator: 3.0832194089889526
# epoch 216 finished in 4.904103994369507 s
#
#
# starting epoch 217
# avg loss over epoch,
# Discriminator: 0.28450708091259
# Generator: 3.226237654685974
# epoch 217 finished in 4.9013659954071045 s
#
#
# starting epoch 218
# avg loss over epoch,
# Discriminator: 0.14882636442780495
# Generator: 4.353213906288147
# epoch 218 finished in 4.8947038650512695 s
#
#
# starting epoch 219
# avg loss over epoch,
# Discriminator: 0.22969487309455872
# Generator: 3.34619003534317
# epoch 219 finished in 4.89893102645874 s
#
#
# starting epoch 220
# avg loss over epoch,
# Discriminator: 0.38499733805656433
# Generator: 3.673512279987335
# epoch 220 finished in 4.912250280380249 s
#
#
# starting epoch 221
# avg loss over epoch,
# Discriminator: 0.2409917637705803
# Generator: 2.5979679822921753
# epoch 221 finished in 4.9048683643341064 s
#
#
# starting epoch 222
# avg loss over epoch,
# Discriminator: 0.19136494398117065
# Generator: 2.9260177612304688
# epoch 222 finished in 4.913352966308594 s
#
#
# starting epoch 223
# avg loss over epoch,
# Discriminator: 0.21159565448760986
# Generator: 3.2102030515670776
# epoch 223 finished in 4.903825759887695 s
#
#
# starting epoch 224
# avg loss over epoch,
# Discriminator: 0.3570208214223385
# Generator: 5.906805992126465
# epoch 224 finished in 4.904308080673218 s
#
#
# starting epoch 225
# avg loss over epoch,
# Discriminator: 0.3515796586871147
# Generator: 4.152478575706482
# epoch 225 finished in 4.9246790409088135 s
#
#
# starting epoch 226
# avg loss over epoch,
# Discriminator: 0.2543721944093704
# Generator: 2.35670268535614
# epoch 226 finished in 4.904780387878418 s
#
#
# starting epoch 227
# avg loss over epoch,
# Discriminator: 0.23477474227547646
# Generator: 2.6661208271980286
# epoch 227 finished in 4.901945352554321 s
#
#
# starting epoch 228
# avg loss over epoch,
# Discriminator: 0.2902500480413437
# Generator: 2.5415924191474915
# epoch 228 finished in 4.911055326461792 s
#
#
# starting epoch 229
# avg loss over epoch,
# Discriminator: 0.28470703959465027
# Generator: 2.503644049167633
# epoch 229 finished in 4.917237281799316 s
#
#
# starting epoch 230
# avg loss over epoch,
# Discriminator: 0.3077438473701477
# Generator: 2.7098666429519653
# epoch 230 finished in 4.910150527954102 s
#
#
# starting epoch 231
# avg loss over epoch,
# Discriminator: 0.28154223784804344
# Generator: 4.058323979377747
# epoch 231 finished in 4.909549951553345 s
#
#
# starting epoch 232
# avg loss over epoch,
# Discriminator: 0.4044570103287697
# Generator: 4.05150830745697
# epoch 232 finished in 4.9124755859375 s
#
#
# starting epoch 233
# avg loss over epoch,
# Discriminator: 0.24551163613796234
# Generator: 3.0862114429473877
# epoch 233 finished in 4.903022289276123 s
#
#
# starting epoch 234
# avg loss over epoch,
# Discriminator: 0.30709556490182877
# Generator: 3.2201815247535706
# epoch 234 finished in 4.899329900741577 s
#
#
# starting epoch 235
# avg loss over epoch,
# Discriminator: 0.32479384168982506
# Generator: 3.999661862850189
# epoch 235 finished in 4.923776388168335 s
#
#
# starting epoch 236
# avg loss over epoch,
# Discriminator: 0.3320160582661629
# Generator: 3.901868224143982
# epoch 236 finished in 4.9099438190460205 s
#
#
# starting epoch 237
# avg loss over epoch,
# Discriminator: 0.3967338874936104
# Generator: 3.496015787124634
# epoch 237 finished in 4.915022850036621 s
#
#
# starting epoch 238
# avg loss over epoch,
# Discriminator: 0.31263840943574905
# Generator: 3.042981207370758
# epoch 238 finished in 4.92152214050293 s
#
#
# starting epoch 239
# avg loss over epoch,
# Discriminator: 0.26819487288594246
# Generator: 3.1875796914100647
# epoch 239 finished in 4.906713008880615 s
#
#
# starting epoch 240
# avg loss over epoch,
# Discriminator: 0.20236355811357498
# Generator: 3.7469415068626404
# epoch 240 finished in 4.910654067993164 s
#
#
# starting epoch 241
# avg loss over epoch,
# Discriminator: 0.49968672543764114
# Generator: 3.940539538860321
# epoch 241 finished in 4.8883137702941895 s
#
#
# starting epoch 242
# avg loss over epoch,
# Discriminator: 0.21946302615106106
# Generator: 4.353009581565857
# epoch 242 finished in 4.902869701385498 s
#
#
# starting epoch 243
# avg loss over epoch,
# Discriminator: 0.23531227931380272
# Generator: 3.746503472328186
# epoch 243 finished in 4.894575119018555 s
#
#
# starting epoch 244
# avg loss over epoch,
# Discriminator: 0.34146133437752724
# Generator: 4.091227889060974
# epoch 244 finished in 4.890085220336914 s
#
#
# starting epoch 245
# avg loss over epoch,
# Discriminator: 0.28697924315929413
# Generator: 2.7784876227378845
# epoch 245 finished in 4.875272750854492 s
#
#
# starting epoch 246
# avg loss over epoch,
# Discriminator: 0.29315540194511414
# Generator: 3.355374753475189
# epoch 246 finished in 4.906100511550903 s
#
#
# starting epoch 247
# avg loss over epoch,
# Discriminator: 0.38638290762901306
# Generator: 3.361817717552185
# epoch 247 finished in 4.889691352844238 s
#
#
# starting epoch 248
# avg loss over epoch,
# Discriminator: 0.3627951592206955
# Generator: 3.4165908694267273
# epoch 248 finished in 4.883192539215088 s
#
#
# starting epoch 249
# avg loss over epoch,
# Discriminator: 0.20588728412985802
# Generator: 3.6651132702827454
# epoch 249 finished in 4.88517951965332 s
#
#
# starting epoch 250
# avg loss over epoch,
# Discriminator: 0.21954947337508202
# Generator: 3.607979416847229
# epoch 250 finished in 4.8848795890808105 s
#
#
# starting epoch 251
# avg loss over epoch,
# Discriminator: 0.21557962894439697
# Generator: 4.020541191101074
# epoch 251 finished in 4.88405704498291 s
#
#
# starting epoch 252
# avg loss over epoch,
# Discriminator: 0.4829823225736618
# Generator: 4.1991952657699585
# epoch 252 finished in 4.901204824447632 s
#
#
# starting epoch 253
# avg loss over epoch,
# Discriminator: 0.23734025657176971
# Generator: 3.937910258769989
# epoch 253 finished in 4.908485651016235 s
#
#
# starting epoch 254
# avg loss over epoch,
# Discriminator: 0.35079893469810486
# Generator: 3.693821966648102
# epoch 254 finished in 4.876546144485474 s
#
#
# starting epoch 255
# avg loss over epoch,
# Discriminator: 0.2770873159170151
# Generator: 3.337274491786957
# epoch 255 finished in 4.8860924243927 s
#
#
# starting epoch 256
# avg loss over epoch,
# Discriminator: 0.31256237253546715
# Generator: 4.006921589374542
# epoch 256 finished in 4.889834403991699 s
#
#
# starting epoch 257
# avg loss over epoch,
# Discriminator: 0.20691005885601044
# Generator: 3.8383498191833496
# epoch 257 finished in 4.8817458152771 s
#
#
# starting epoch 258
# avg loss over epoch,
# Discriminator: 0.4344014972448349
# Generator: 2.8748666048049927
# epoch 258 finished in 4.887110233306885 s
#
#
# starting epoch 259
# avg loss over epoch,
# Discriminator: 0.31666379421949387
# Generator: 2.488515317440033
# epoch 259 finished in 4.879456281661987 s
#
#
# starting epoch 260
# avg loss over epoch,
# Discriminator: 0.3277023807168007
# Generator: 3.0323660373687744
# epoch 260 finished in 4.892051696777344 s
#
#
# starting epoch 261
# avg loss over epoch,
# Discriminator: 0.25350817665457726
# Generator: 3.216944634914398
# epoch 261 finished in 4.883379220962524 s
#
#
# starting epoch 262
# avg loss over epoch,
# Discriminator: 0.17625105753540993
# Generator: 3.466870903968811
# epoch 262 finished in 4.886751651763916 s
#
#
# starting epoch 263
# avg loss over epoch,
# Discriminator: 0.18250415474176407
# Generator: 3.883263111114502
# epoch 263 finished in 4.893008708953857 s
#
#
# starting epoch 264
# avg loss over epoch,
# Discriminator: 0.4025745615363121
# Generator: 4.032073020935059
# epoch 264 finished in 4.902338981628418 s
#
#
# starting epoch 265
# avg loss over epoch,
# Discriminator: 0.25602855905890465
# Generator: 3.5210753679275513
# epoch 265 finished in 4.8694376945495605 s
#
#
# starting epoch 266
# avg loss over epoch,
# Discriminator: 0.24676015228033066
# Generator: 3.0798441767692566
# epoch 266 finished in 4.877061367034912 s
#
#
# starting epoch 267
# avg loss over epoch,
# Discriminator: 0.20079266279935837
# Generator: 3.4873419404029846
# epoch 267 finished in 4.87386679649353 s
#
#
# starting epoch 268
# avg loss over epoch,
# Discriminator: 0.2919840458780527
# Generator: 3.1137997806072235
# epoch 268 finished in 4.876177787780762 s
#
#
# starting epoch 269
# avg loss over epoch,
# Discriminator: 0.30853481963276863
# Generator: 3.187850832939148
# epoch 269 finished in 4.879527568817139 s
#
#
# starting epoch 270
# avg loss over epoch,
# Discriminator: 0.2297465056180954
# Generator: 2.9832430481910706
# epoch 270 finished in 4.8892011642456055 s
#
#
# starting epoch 271
# avg loss over epoch,
# Discriminator: 0.21519427746534348
# Generator: 3.3053548336029053
# epoch 271 finished in 4.882727146148682 s
#
#
# starting epoch 272
# avg loss over epoch,
# Discriminator: 0.38587822765111923
# Generator: 3.4993655681610107
# epoch 272 finished in 4.869509935379028 s
#
#
# starting epoch 273
# avg loss over epoch,
# Discriminator: 0.2793760858476162
# Generator: 3.3004737496376038
# epoch 273 finished in 4.8775341510772705 s
#
#
# starting epoch 274
# avg loss over epoch,
# Discriminator: 0.2275131270289421
# Generator: 3.940365791320801
# epoch 274 finished in 4.897924184799194 s
#
#
# starting epoch 275
# avg loss over epoch,
# Discriminator: 0.27153412252664566
# Generator: 4.325293779373169
# epoch 275 finished in 4.886219501495361 s
#
#
# starting epoch 276
# avg loss over epoch,
# Discriminator: 0.229754239320755
# Generator: 2.9373180270195007
# epoch 276 finished in 4.872639894485474 s
#
#
# starting epoch 277
# avg loss over epoch,
# Discriminator: 0.21356404572725296
# Generator: 3.5673550963401794
# epoch 277 finished in 4.885087251663208 s
#
#
# starting epoch 278
# avg loss over epoch,
# Discriminator: 0.29864034801721573
# Generator: 3.05523082613945
# epoch 278 finished in 4.879958629608154 s
#
#
# starting epoch 279
# avg loss over epoch,
# Discriminator: 0.2848696708679199
# Generator: 3.6834415793418884
# epoch 279 finished in 4.885281324386597 s
#
#
# starting epoch 280
# avg loss over epoch,
# Discriminator: 0.339621365070343
# Generator: 3.6079235672950745
# epoch 280 finished in 4.879121780395508 s
#
#
# starting epoch 281
# avg loss over epoch,
# Discriminator: 0.23502817749977112
# Generator: 2.9550816416740417
# epoch 281 finished in 4.884943723678589 s
#
#
# starting epoch 282
# avg loss over epoch,
# Discriminator: 0.20001792535185814
# Generator: 2.8781399726867676
# epoch 282 finished in 4.880335807800293 s
#
#
# starting epoch 283
# avg loss over epoch,
# Discriminator: 0.2508081905543804
# Generator: 3.272470772266388
# epoch 283 finished in 4.8683459758758545 s
#
#
# starting epoch 284
# avg loss over epoch,
# Discriminator: 0.4663359224796295
# Generator: 3.8584457635879517
# epoch 284 finished in 4.891606092453003 s
#
#
# starting epoch 285
# avg loss over epoch,
# Discriminator: 0.2985055074095726
# Generator: 2.6891966462135315
# epoch 285 finished in 4.87986159324646 s
#
#
# starting epoch 286
# avg loss over epoch,
# Discriminator: 0.1918199025094509
# Generator: 3.11922550201416
# epoch 286 finished in 4.866667985916138 s
#
#
# starting epoch 287
# avg loss over epoch,
# Discriminator: 0.15542700700461864
# Generator: 3.475255072116852
# epoch 287 finished in 4.878756523132324 s
#
#
# starting epoch 288
# avg loss over epoch,
# Discriminator: 0.3309892937541008
# Generator: 3.6708164513111115
# epoch 288 finished in 4.873109340667725 s
#
#
# starting epoch 289
# avg loss over epoch,
# Discriminator: 0.18446633219718933
# Generator: 2.9621853828430176
# epoch 289 finished in 4.881479740142822 s
#
#
# starting epoch 290
# avg loss over epoch,
# Discriminator: 0.29303739219903946
# Generator: 3.3226399421691895
# epoch 290 finished in 4.882889986038208 s
#
#
# starting epoch 291
# avg loss over epoch,
# Discriminator: 0.32421351224184036
# Generator: 3.733826696872711
# epoch 291 finished in 4.8873231410980225 s
#
#
# starting epoch 292
# avg loss over epoch,
# Discriminator: 0.532115314155817
# Generator: 3.5489640533924103
# epoch 292 finished in 4.872235536575317 s
#
#
# starting epoch 293
# avg loss over epoch,
# Discriminator: 0.19197818636894226
# Generator: 2.5002997517585754
# epoch 293 finished in 4.865346908569336 s
#
#
# starting epoch 294
# avg loss over epoch,
# Discriminator: 0.23748528212308884
# Generator: 3.1847111582756042
# epoch 294 finished in 4.869513988494873 s
#
#
# starting epoch 295
# avg loss over epoch,
# Discriminator: 0.2624773234128952
# Generator: 3.436763823032379
# epoch 295 finished in 4.882822275161743 s
#
#
# starting epoch 296
# avg loss over epoch,
# Discriminator: 0.27747227624058723
# Generator: 2.688580811023712
# epoch 296 finished in 4.86115837097168 s
#
#
# starting epoch 297
# avg loss over epoch,
# Discriminator: 0.3181064650416374
# Generator: 3.2202406525611877
# epoch 297 finished in 4.870885133743286 s
#
#
# starting epoch 298
# avg loss over epoch,
# Discriminator: 0.16231820732355118
# Generator: 3.1280198097229004
# epoch 298 finished in 4.868284225463867 s
#
#
# starting epoch 299
# avg loss over epoch,
# Discriminator: 0.1802087314426899
# Generator: 3.4824796319007874
# epoch 299 finished in 4.90195894241333 s
#
#
# starting epoch 300
# avg loss over epoch,
# Discriminator: 0.7291353419423103
# Generator: 5.375560760498047
# epoch 300 finished in 4.872452259063721 s
#
#
# starting epoch 301
# avg loss over epoch,
# Discriminator: 0.3334701545536518
# Generator: 3.2663183212280273
# epoch 301 finished in 4.873460292816162 s
#
#
# starting epoch 302
# avg loss over epoch,
# Discriminator: 0.3394745662808418
# Generator: 2.370836555957794
# epoch 302 finished in 4.880565643310547 s
#
#
# starting epoch 303
# avg loss over epoch,
# Discriminator: 0.3385898247361183
# Generator: 2.3409705758094788
# epoch 303 finished in 4.8819739818573 s
#
#
# starting epoch 304
# avg loss over epoch,
# Discriminator: 0.24875780567526817
# Generator: 2.93194717168808
# epoch 304 finished in 4.876657962799072 s
#
#
# starting epoch 305
# avg loss over epoch,
# Discriminator: 0.2345304824411869
# Generator: 2.6634392738342285
# epoch 305 finished in 4.8788440227508545 s
#
#
# starting epoch 306
# avg loss over epoch,
# Discriminator: 0.22698157280683517
# Generator: 3.384119153022766
# epoch 306 finished in 4.894051551818848 s
#
#
# starting epoch 307
# avg loss over epoch,
# Discriminator: 0.18945226073265076
# Generator: 3.8775064945220947
# epoch 307 finished in 4.869399309158325 s
#
#
# starting epoch 308
# avg loss over epoch,
# Discriminator: 0.3233083002269268
# Generator: 2.9794753193855286
# epoch 308 finished in 4.870232582092285 s
#
#
# starting epoch 309
# avg loss over epoch,
# Discriminator: 0.25927960127592087
# Generator: 3.6260414123535156
# epoch 309 finished in 4.874125242233276 s
#
#
# starting epoch 310
# avg loss over epoch,
# Discriminator: 0.26226457208395004
# Generator: 3.7842480540275574
# epoch 310 finished in 4.867857217788696 s
#
#
# starting epoch 311
# avg loss over epoch,
# Discriminator: 0.19830578193068504
# Generator: 3.925641357898712
# epoch 311 finished in 4.866889238357544 s
#
#
# starting epoch 312
# avg loss over epoch,
# Discriminator: 0.18620004504919052
# Generator: 3.3376983404159546
# epoch 312 finished in 4.864327907562256 s
#
#
# starting epoch 313
# avg loss over epoch,
# Discriminator: 0.1790953315794468
# Generator: 3.388433575630188
# epoch 313 finished in 4.881477117538452 s
#
#
# starting epoch 314
# avg loss over epoch,
# Discriminator: 0.20260490477085114
# Generator: 3.579721450805664
# epoch 314 finished in 4.869370222091675 s
#
#
# starting epoch 315
# avg loss over epoch,
# Discriminator: 0.36382509768009186
# Generator: 4.6020766496658325
# epoch 315 finished in 4.878108263015747 s
#
#
# starting epoch 316
# avg loss over epoch,
# Discriminator: 0.3076837584376335
# Generator: 3.2105581164360046
# epoch 316 finished in 4.873798847198486 s
#
#
# starting epoch 317
# avg loss over epoch,
# Discriminator: 0.18496686965227127
# Generator: 3.383880138397217
# ...
# Generator: 3.198031425476074
# epoch 393 finished in 4.871560573577881 s
#
#
# starting epoch 394
# avg loss over epoch,
# Discriminator: 0.2967088147997856
# Generator: 2.782032012939453
# epoch 394 finished in 4.887119770050049 s
#
#
# starting epoch 395
# avg loss over epoch,
# Discriminator: 0.19642046466469765
# Generator: 2.870271384716034
# epoch 395 finished in 4.8918561935424805 s
#
#
# starting epoch 396
# avg loss over epoch,
# Discriminator: 0.29235169664025307
# Generator: 3.756933867931366
# epoch 396 finished in 4.877989053726196 s
#
#
# starting epoch 397
# avg loss over epoch,
# Discriminator: 0.2857610285282135
# Generator: 2.817440092563629
# epoch 397 finished in 4.873920679092407 s
#
#
# starting epoch 398
# avg loss over epoch,
# Discriminator: 0.24180395156145096
# Generator: 2.966143786907196
# epoch 398 finished in 4.890105247497559 s
#
#
# starting epoch 399
# avg loss over epoch,
# Discriminator: 0.2403079718351364
# Generator: 3.3075016736984253
# epoch 399 finished in 4.871525287628174 s
#
#
# starting epoch 400
# avg loss over epoch,
# Discriminator: 0.3280895724892616
# Generator: 3.774945020675659
# epoch 400 finished in 4.89799165725708 s
#
#
# starting epoch 401
# avg loss over epoch,
# Discriminator: 0.23325544595718384
# Generator: 2.9113691449165344
# epoch 401 finished in 4.890993356704712 s
#
#
# starting epoch 402
# avg loss over epoch,
# Discriminator: 0.23363260924816132
# Generator: 2.751102030277252
# epoch 402 finished in 4.888887166976929 s
#
#
# starting epoch 403
# avg loss over epoch,
# Discriminator: 0.3829697296023369
# Generator: 3.2940719723701477
# epoch 403 finished in 4.8876025676727295 s
#
#
# starting epoch 404
# avg loss over epoch,
# Discriminator: 0.3620593026280403
# Generator: 2.8332177996635437
# epoch 404 finished in 4.897095441818237 s
#
#
# starting epoch 405
# avg loss over epoch,
# Discriminator: 0.18771013617515564
# Generator: 2.8064658641815186
# epoch 405 finished in 4.9032957553863525 s
#
#
# starting epoch 406
# avg loss over epoch,
# Discriminator: 0.31717927753925323
# Generator: 2.3364148437976837
# epoch 406 finished in 4.893131732940674 s
#
#
# starting epoch 407
# avg loss over epoch,
# Discriminator: 0.30341583490371704
# Generator: 2.4597830772399902
# epoch 407 finished in 4.902564764022827 s
#
#
# starting epoch 408
# avg loss over epoch,
# Discriminator: 0.3138028532266617
# Generator: 3.136730194091797
# epoch 408 finished in 4.903932809829712 s
#
#
# starting epoch 409
# avg loss over epoch,
# Discriminator: 0.23917707055807114
# Generator: 3.0725194215774536
# epoch 409 finished in 4.890785217285156 s
#
#
# starting epoch 410
# avg loss over epoch,
# Discriminator: 0.3083275929093361
# Generator: 3.217026650905609
# epoch 410 finished in 4.89553689956665 s
#
#
# starting epoch 411
# avg loss over epoch,
# Discriminator: 0.32683998346328735
# Generator: 3.421893060207367
# epoch 411 finished in 4.897852420806885 s
#
#
# starting epoch 412
# avg loss over epoch,
# Discriminator: 0.23404806852340698
# Generator: 3.1333335041999817
# epoch 412 finished in 4.8928186893463135 s
#
#
# starting epoch 413
# avg loss over epoch,
# Discriminator: 0.30783727020025253
# Generator: 3.347511351108551
# epoch 413 finished in 4.90699577331543 s
#
#
# starting epoch 414
# avg loss over epoch,
# Discriminator: 0.2831539176404476
# Generator: 3.6074447631835938
# epoch 414 finished in 4.892102956771851 s
#
#
# starting epoch 415
# avg loss over epoch,
# Discriminator: 0.4437243416905403
# Generator: 3.7957844734191895
# epoch 415 finished in 4.900721788406372 s
#
#
# starting epoch 416
# avg loss over epoch,
# Discriminator: 0.3631272129714489
# Generator: 3.042816936969757
# epoch 416 finished in 4.905563592910767 s
#
#
# starting epoch 417
# avg loss over epoch,
# Discriminator: 0.2689875513315201
# Generator: 2.9981818795204163
# epoch 417 finished in 4.898105621337891 s
#
#
# starting epoch 418
# avg loss over epoch,
# Discriminator: 0.22337568551301956
# Generator: 2.912836968898773
# epoch 418 finished in 4.89235782623291 s
#
#
# starting epoch 419
# avg loss over epoch,
# Discriminator: 0.23436100408434868
# Generator: 3.5145848989486694
# epoch 419 finished in 4.900008201599121 s
#
#
# starting epoch 420
# avg loss over epoch,
# Discriminator: 0.30731816962361336
# Generator: 4.063674330711365
# epoch 420 finished in 4.881833076477051 s
#
#
# starting epoch 421
# avg loss over epoch,
# Discriminator: 0.3350816145539284
# Generator: 3.6402231454849243
# epoch 421 finished in 4.8860743045806885 s
#
#
# starting epoch 422
# avg loss over epoch,
# Discriminator: 0.3536085784435272
# Generator: 2.922910749912262
# epoch 422 finished in 4.899996519088745 s
#
#
# starting epoch 423
# avg loss over epoch,
# Discriminator: 0.20578083023428917
# Generator: 3.284517467021942
# epoch 423 finished in 4.900365352630615 s
#
#
# starting epoch 424
# avg loss over epoch,
# Discriminator: 0.2720317989587784
# Generator: 3.297812521457672
# epoch 424 finished in 4.889683961868286 s
#
#
# starting epoch 425
# avg loss over epoch,
# Discriminator: 0.26138195395469666
# Generator: 3.565744161605835
# epoch 425 finished in 4.897556304931641 s
#
#
# starting epoch 426
# avg loss over epoch,
# Discriminator: 0.2529601901769638
# Generator: 3.2714297771453857
# epoch 426 finished in 4.900399208068848 s
#
#
# starting epoch 427
# avg loss over epoch,
# Discriminator: 0.22272805124521255
# Generator: 3.381681501865387
# epoch 427 finished in 4.894955396652222 s
#
#
# starting epoch 428
# avg loss over epoch,
# Discriminator: 0.3114873841404915
# Generator: 4.578502774238586
# epoch 428 finished in 4.90397310256958 s
#
#
# starting epoch 429
# avg loss over epoch,
# Discriminator: 0.445999201387167
# Generator: 3.326325297355652
# epoch 429 finished in 4.898205280303955 s
#
#
# starting epoch 430
# avg loss over epoch,
# Discriminator: 0.27687111124396324
# Generator: 3.463765561580658
# epoch 430 finished in 4.901273250579834 s
#
#
# starting epoch 431
# avg loss over epoch,
# Discriminator: 0.22046766430139542
# Generator: 3.552758574485779
# epoch 431 finished in 4.890202760696411 s
#
#
# starting epoch 432
# avg loss over epoch,
# Discriminator: 0.2899961322546005
# Generator: 3.0924965143203735
# epoch 432 finished in 4.914588928222656 s
#
#
# starting epoch 433
# avg loss over epoch,
# Discriminator: 0.28230584412813187
# Generator: 3.1977813243865967
# epoch 433 finished in 4.896320581436157 s
#
#
# starting epoch 434
# avg loss over epoch,
# Discriminator: 0.30810125172138214
# Generator: 3.5585013031959534
# epoch 434 finished in 4.879466533660889 s
#
#
# starting epoch 435
# avg loss over epoch,
# Discriminator: 0.24132126569747925
# Generator: 3.3574776649475098
# epoch 435 finished in 4.8983025550842285 s
#
#
# starting epoch 436
# avg loss over epoch,
# Discriminator: 0.23188862204551697
# Generator: 3.5676055550575256
# epoch 436 finished in 4.907381772994995 s
#
#
# starting epoch 437
# avg loss over epoch,
# Discriminator: 0.26029637083411217
# Generator: 3.4560972452163696
# epoch 437 finished in 4.884884834289551 s
#
#
# starting epoch 438
# avg loss over epoch,
# Discriminator: 0.21043578162789345
# Generator: 3.3453769087791443
# epoch 438 finished in 4.865258693695068 s
#
#
# starting epoch 439
# avg loss over epoch,
# Discriminator: 0.17910394445061684
# Generator: 3.2470157742500305
# epoch 439 finished in 4.878081798553467 s
#
#
# starting epoch 440
# avg loss over epoch,
# Discriminator: 0.1853768676519394
# Generator: 3.3065651059150696
# epoch 440 finished in 4.889432191848755 s
#
#
# starting epoch 441
# avg loss over epoch,
# Discriminator: 0.3818145766854286
# Generator: 3.671432137489319
# epoch 441 finished in 4.887432813644409 s
#
#
# starting epoch 442
# avg loss over epoch,
# Discriminator: 0.15601116605103016
# Generator: 3.3261762261390686
# epoch 442 finished in 4.871201992034912 s
#
#
# starting epoch 443
# avg loss over epoch,
# Discriminator: 0.2439296394586563
# Generator: 3.4388771057128906
# epoch 443 finished in 4.880550146102905 s
#
#
# starting epoch 444
# avg loss over epoch,
# Discriminator: 0.2636023089289665
# Generator: 3.1144620776176453
# epoch 444 finished in 4.883550405502319 s
#
#
# starting epoch 445
# avg loss over epoch,
# Discriminator: 0.3173796385526657
# Generator: 3.901672124862671
# epoch 445 finished in 4.8868513107299805 s
#
#
# starting epoch 446
# avg loss over epoch,
# Discriminator: 0.5178026333451271
# Generator: 3.749473214149475
# epoch 446 finished in 4.882016658782959 s
#
#
# starting epoch 447
# avg loss over epoch,
# Discriminator: 0.3325161188840866
# Generator: 3.325802445411682
# epoch 447 finished in 4.89562463760376 s
#
#
# starting epoch 448
# avg loss over epoch,
# Discriminator: 0.29689832776784897
# Generator: 3.398917496204376
# epoch 448 finished in 4.887190103530884 s
#
#
# starting epoch 449
# avg loss over epoch,
# Discriminator: 0.2361181564629078
# Generator: 3.058491051197052
# epoch 449 finished in 4.886315107345581 s
#
#
# starting epoch 450
# avg loss over epoch,
# Discriminator: 0.2713913843035698
# Generator: 2.606961965560913
# epoch 450 finished in 4.885558843612671 s
#
#
# starting epoch 451
# avg loss over epoch,
# Discriminator: 0.17136703804135323
# Generator: 3.228245258331299
# epoch 451 finished in 4.87940526008606 s
#
#
# starting epoch 452
# avg loss over epoch,
# Discriminator: 0.38867801427841187
# Generator: 2.957970678806305
# epoch 452 finished in 4.879289865493774 s
#
#
# starting epoch 453
# avg loss over epoch,
# Discriminator: 0.2432856373488903
# Generator: 2.846607744693756
# epoch 453 finished in 4.877985239028931 s
#
#
# starting epoch 454
# avg loss over epoch,
# Discriminator: 0.19475418701767921
# Generator: 2.9006965160369873
# epoch 454 finished in 4.887057542800903 s
#
#
# starting epoch 455
# avg loss over epoch,
# Discriminator: 0.3011288642883301
# Generator: 3.11592173576355
# epoch 455 finished in 4.872169017791748 s
#
#
# starting epoch 456
# avg loss over epoch,
# Discriminator: 0.30368778109550476
# Generator: 3.615614891052246
# epoch 456 finished in 4.87321662902832 s
#
#
# starting epoch 457
# avg loss over epoch,
# Discriminator: 0.21290180832147598
# Generator: 3.4249002933502197
# epoch 457 finished in 4.866261959075928 s
#
#
# starting epoch 458
# avg loss over epoch,
# Discriminator: 0.16905821673572063
# Generator: 3.9500510692596436
# epoch 458 finished in 4.877744197845459 s
#
#
# starting epoch 459
# avg loss over epoch,
# Discriminator: 0.29495614767074585
# Generator: 3.105867564678192
# epoch 459 finished in 4.864830255508423 s
#
#
# starting epoch 460
# avg loss over epoch,
# Discriminator: 0.24972573295235634
# Generator: 3.3985859751701355
# epoch 460 finished in 4.880344390869141 s
#
#
# starting epoch 461
# avg loss over epoch,
# Discriminator: 0.22032612934708595
# Generator: 3.3644339442253113
# epoch 461 finished in 4.86896276473999 s
#
#
# starting epoch 462
# avg loss over epoch,
# Discriminator: 0.471475787460804
# Generator: 3.793451189994812
# epoch 462 finished in 4.8840014934539795 s
#
#
# starting epoch 463
# avg loss over epoch,
# Discriminator: 0.306803897023201
# Generator: 3.092704653739929
# epoch 463 finished in 4.884462118148804 s
#
#
# starting epoch 464
# avg loss over epoch,
# Discriminator: 0.24264147877693176
# Generator: 3.246512472629547
# epoch 464 finished in 4.873107433319092 s
#
#
# starting epoch 465
# avg loss over epoch,
# Discriminator: 0.2421041987836361
# Generator: 3.0984609723091125
# epoch 465 finished in 4.8773908615112305 s
#
#
# starting epoch 466
# avg loss over epoch,
# Discriminator: 0.2859157770872116
# Generator: 2.8501304388046265
# epoch 466 finished in 4.866458892822266 s
#
#
# starting epoch 467
# avg loss over epoch,
# Discriminator: 0.26816630735993385
# Generator: 3.0683635473251343
# epoch 467 finished in 4.869199752807617 s
#
#
# starting epoch 468
# avg loss over epoch,
# Discriminator: 0.30570706352591515
# Generator: 3.2489311695098877
# epoch 468 finished in 4.883925914764404 s
#
#
# starting epoch 469
# avg loss over epoch,
# Discriminator: 0.252235721796751
# Generator: 3.185027599334717
# epoch 469 finished in 4.880753993988037 s
#
#
# starting epoch 470
# avg loss over epoch,
# Discriminator: 0.22778373584151268
# Generator: 3.3886635303497314
# epoch 470 finished in 4.8824217319488525 s
#
#
# starting epoch 471
# avg loss over epoch,
# Discriminator: 0.15552731603384018
# Generator: 3.4866060614585876
# epoch 471 finished in 4.879976272583008 s
#
#
# starting epoch 472
# avg loss over epoch,
# Discriminator: 0.2833103686571121
# Generator: 2.998691737651825
# epoch 472 finished in 4.876155853271484 s
#
#
# starting epoch 473
# avg loss over epoch,
# Discriminator: 0.25900136306881905
# Generator: 3.7735425233840942
# epoch 473 finished in 4.876806735992432 s
#
#
# starting epoch 474
# avg loss over epoch,
# Discriminator: 0.2796289660036564
# Generator: 4.23363196849823
# epoch 474 finished in 4.8726232051849365 s
#
#
# starting epoch 475
# avg loss over epoch,
# Discriminator: 0.23642514273524284
# Generator: 3.2448678612709045
# epoch 475 finished in 4.881665468215942 s
#
#
# starting epoch 476
# avg loss over epoch,
# Discriminator: 0.25563137233257294
# Generator: 3.219219207763672
# epoch 476 finished in 4.886120319366455 s
#
#
# starting epoch 477
# avg loss over epoch,
# Discriminator: 0.260998010635376
# Generator: 3.096222162246704
# epoch 477 finished in 4.878421306610107 s
#
#
# starting epoch 478
# avg loss over epoch,
# Discriminator: 0.2427912801504135
# Generator: 3.1041529774665833
# epoch 478 finished in 4.869074821472168 s
#
#
# starting epoch 479
# avg loss over epoch,
# Discriminator: 0.25088463723659515
# Generator: 3.221857190132141
# epoch 479 finished in 4.877743244171143 s
#
#
# starting epoch 480
# avg loss over epoch,
# Discriminator: 0.3372110426425934
# Generator: 3.876620054244995
# epoch 480 finished in 4.86211371421814 s
#
#
# starting epoch 481
# avg loss over epoch,
# Discriminator: 0.22206875309348106
# Generator: 3.1702573895454407
# epoch 481 finished in 4.867704391479492 s
#
#
# starting epoch 482
# avg loss over epoch,
# Discriminator: 0.23882022500038147
# Generator: 3.177837610244751
# epoch 482 finished in 4.870550632476807 s
#
#
# starting epoch 483
# avg loss over epoch,
# Discriminator: 0.28323789313435555
# Generator: 3.139585494995117
# epoch 483 finished in 4.874206066131592 s
#
#
# starting epoch 484
# avg loss over epoch,
# Discriminator: 0.3062715083360672
# Generator: 3.393259584903717
# epoch 484 finished in 4.869095802307129 s
#
#
# starting epoch 485
# avg loss over epoch,
# Discriminator: 0.3222517818212509
# Generator: 3.192708432674408
# epoch 485 finished in 4.867240905761719 s
#
#
# starting epoch 486
# avg loss over epoch,
# Discriminator: 0.2958063520491123
# Generator: 3.2884503602981567
# epoch 486 finished in 4.894134759902954 s
#
#
# starting epoch 487
# avg loss over epoch,
# Discriminator: 0.43856658041477203
# Generator: 3.3123985528945923
# epoch 487 finished in 4.887277364730835 s
#
#
# starting epoch 488
# avg loss over epoch,
# Discriminator: 0.18385309725999832
# Generator: 3.382099986076355
# epoch 488 finished in 4.8666675090789795 s
#
#
# starting epoch 489
# avg loss over epoch,
# Discriminator: 0.21753942593932152
# Generator: 3.6159892082214355
# epoch 489 finished in 4.873263359069824 s
#
#
# starting epoch 490
# avg loss over epoch,
# Discriminator: 0.2017788290977478
# Generator: 3.8665887117385864
# epoch 490 finished in 4.875641107559204 s
#
#
# starting epoch 491
# avg loss over epoch,
# Discriminator: 0.23356817290186882
# Generator: 4.153729736804962
# epoch 491 finished in 4.867879867553711 s
#
#
# starting epoch 492
# avg loss over epoch,
# Discriminator: 0.3657374456524849
# Generator: 3.6028974652290344
# epoch 492 finished in 4.861375093460083 s
#
#
# starting epoch 493
# avg loss over epoch,
# Discriminator: 0.25308869779109955
# Generator: 4.236843287944794
# epoch 493 finished in 4.866556406021118 s
#
#
# starting epoch 494
# avg loss over epoch,
# Discriminator: 0.5181599855422974
# Generator: 4.2475844621658325
# epoch 494 finished in 4.858622789382935 s
#
#
# starting epoch 495
# avg loss over epoch,
# Discriminator: 0.4117712453007698
# Generator: 3.0577961206436157
# epoch 495 finished in 4.871077537536621 s
#
#
# starting epoch 496
# avg loss over epoch,
# Discriminator: 0.4257741868495941
# Generator: 3.1403247117996216
# epoch 496 finished in 4.864023685455322 s
#
#
# starting epoch 497
# avg loss over epoch,
# Discriminator: 0.2023620642721653
# Generator: 3.380043685436249
# epoch 497 finished in 4.8725666999816895 s
#
#
# starting epoch 498
# avg loss over epoch,
# Discriminator: 0.18977168202400208
# Generator: 3.5227686166763306
# epoch 498 finished in 4.875449180603027 s
#
#
# starting epoch 499
# avg loss over epoch,
# Discriminator: 0.2555510737001896
# Generator: 3.287025809288025
# epoch 499 finished in 4.85781717300415 s

# %%
plt.figure(figsize=(20,10))

plt.plot(gan_loss)
plt.plot(disc_loss)

plt.show()

# %%
from matplotlib import animation

ims = []
fig = plt.figure()
ax = fig.add_axes([0,0,1,1], frameon=False, aspect=1)
ax.set_xticks([]); ax.set_yticks([])

for train_ims in train_images:

    

    im_1 = plt.imshow(train_ims[0,:,:],vmin=0, vmax=1, animated=True) #add first image for test
    
    ims.append([im_1])
    #plt.pause(0.1) 

mp4_writer =  animation.writers['ffmpeg']
writer = mp4_writer(fps=24, metadata=dict(artist='Me'), bitrate=1800)


anim = animation.ArtistAnimation(fig,ims)
anim.save("test_gif_128.mp4", writer= writer)

# %%
fig,axs = plt.subplots(3,3)

print(axs.shape)

for i in range(axs.shape[0]):
    for j in range(axs.shape[1]):
        
        axs[i,j].set_xticks([])
        axs[i,j].set_yticks([])

images = []

#iterate ove images
for imgs in train_images:
    ims = [] 
    for i,img in enumerate(imgs):
        
        line = i%3
        col = int(i/3)
        ims.append(axs[line,col].imshow(img[:,:],vmin=0, vmax=1, animated=True))
    
    images.append(ims)

mp4_writer =  animation.writers['ffmpeg']
writer = mp4_writer(fps=24, metadata=dict(artist='Me'), bitrate=1800)

anim = animation.ArtistAnimation(fig,images)
anim.save("train_grid_128.mp4", writer= writer)
# Out:
# (3, 3)
