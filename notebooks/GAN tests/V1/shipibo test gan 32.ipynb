# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

os.chdir("/content/drive/My Drive/GAN/Shipibo GAN/")
# !ls
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# 'Copy of Shipibo gan test 1.ipynb'   test_gif_128.mp4
#  preproc			     test_gif_2.mp4
# 'Shipibo gan test 1.ipynb'	     test_gif_3.mp4
# 'shipibo test gan 128.ipynb'	     train_grid_128.mp4
# 'shipibo test gan 32.ipynb'	     train_grid.mp4

# %%
from keras.preprocessing.image import load_img,img_to_array
from PIL import Image

def load_images(path,size=32):
    """ loads images into a numpy array and returns them
    """
    img_paths = [path + f  for f in os.listdir(path)]
    print(len(img_paths))
    dataset_shape = (len(img_paths),size,size,3)

    data = np.ndarray(shape=dataset_shape)

    for i,f in enumerate(os.listdir(path)):
        im = Image.open(path + f)
        
        im = np.array(im)
        
        if i % 20 == 0:
            print("loaded ", i,"images" )

        data[i] = im.astype(int)
        

    print(data.shape)

    return data
data = load_images("preproc/32/")
# Out:
# Using TensorFlow backend.
# 402
# loaded  0 images
# loaded  20 images
# loaded  40 images
# loaded  60 images
# loaded  80 images
# loaded  100 images
# loaded  120 images
# loaded  140 images
# loaded  160 images
# loaded  180 images
# loaded  200 images
# loaded  220 images
# loaded  240 images
# loaded  260 images
# loaded  280 images
# loaded  300 images
# loaded  320 images
# loaded  340 images
# loaded  360 images
# loaded  380 images
# loaded  400 images
# (402, 32, 32, 3)

# %%
#warning, only run this once or else load the data all over again
data = (data - 127.5) / 127.5

# %%
test = (data[0] + 1) / 2.0
plt.imshow(test)

# %%
def generate_real_samples(data,n_samples):
    
    rand_indexes = np.random.randint(0,data.shape[0],n_samples)
    
    X_samples = data[rand_indexes]
    y_samples = np.ones((n_samples,1))
    
    return X_samples,y_samples

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Conv2D
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers import LeakyReLU
from keras.optimizers import Adam

def make_discriminator(input_shape=(32,32,3)):
    
    model = Sequential()
    #normal layer
    model.add(Conv2D(64,(3,3),padding="same",input_shape=input_shape))
    model.add(LeakyReLU(alpha=0.2))
    
    #downsample
    model.add(Conv2D(128,(3,3),strides=(2,2),padding="same"))
    
    model.add(LeakyReLU(alpha=0.2))
    
    #downsample
    model.add(Conv2D(128,(3,3),strides=(2,2),padding="same"))
    model.add(LeakyReLU(alpha=0.2))
    
    #downsample
    model.add(Conv2D(256,(3,3),strides=(2,2),padding="same"))
    model.add(LeakyReLU(alpha=0.2))

    #keep this comented for 32x32 version
    #downsample
    # model.add(Conv2D(256,(3,3),strides=(2,2),padding="same"))
    # model.add(LeakyReLU(alpha=0.2))
    
    #flatten then pass through fully connected layer
    model.add(Flatten())
    model.add(Dropout(0.4))
    model.add(Dense(1,activation="sigmoid"))
    
    opt = Adam(lr=0.0002,beta_1=0.5)
    
    model.compile(loss="binary_crossentropy",optimizer=opt,metrics=["accuracy"])
    
    return model

# %%
from keras.layers import Reshape
from keras.layers import Conv2DTranspose

# define the standalone generator model
def make_generator(latent_dim=100):
    model = Sequential()
    # foundation for 4x4 image
    n_nodes = 256 * 4 * 4
    model.add(Dense(n_nodes, input_dim=latent_dim))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Reshape((4, 4, 256)))
    # upsample to 8x8
    model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    # upsample to 16x16
    model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    # upsample to 32x32
    model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    
    #upsample to 64x64
    # model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
    # model.add(LeakyReLU(alpha=0.2))
    
    # output layer
    model.add(Conv2D(3, (3,3), activation='tanh', padding='same'))
    return model

# %%
def generate_latent_points(n_samples,latent_dim=100):
    
    latent_points = np.random.randn(latent_dim*n_samples)
    
    latent_points = latent_points.reshape((n_samples,latent_dim))
    
    return latent_points

def generate_fake_samples(generator,n_samples,latent_dim=100):
    
    #first generate latent points, then pass them to the generator
    
    latent_points = generate_latent_points(n_samples,latent_dim)
    
    X_fake = generator.predict(latent_points)
    
    y_fake = np.zeros((n_samples,1))
    
    return X_fake,y_fake

# %%
def make_gan(discriminator,generator):
    
    model = Sequential()
    
    discriminator.trainable = False
    
    model.add(generator)
    
    model.add(discriminator)
    
    opt = Adam(lr=0.0002, beta_1=0.5)
    model.compile(loss="binary_crossentropy",optimizer=opt)
    
    return model

# %%
import time

def train_gan(data,gan,discriminator,generator,n_epochs=200,batch_size=128):
    batch_per_epoch = int(data.shape[0] / batch_size)
    half_batch = int(batch_size / 2)
    
    n_points = 9
    fixed_latent_points = generate_latent_points(n_points)
    train_images = []
    
    gan_loss = []
    disc_loss = []
    
    
    for epoch in range(n_epochs):
        print("starting epoch",epoch)
        start_time = time.time()
        
        avg_epoch_disc_loss= []
        avg_epoch_gen_loss = []

        for batch in range(batch_per_epoch):
            
            #train the discriminator
            X_real,y_real = generate_real_samples(data,half_batch)
            X_fake,y_fake = generate_fake_samples(generator,half_batch)
            
            X,y = np.vstack((X_real,X_fake)) , np.vstack((y_real, y_fake))
            
            d_loss, _ = discriminator.train_on_batch(X,y)
            
            #train the generator (through the gan model by using the discriminator's error)
            lat_points = generate_latent_points(batch_size)
            y_gan = np.ones((batch_size,1))
            
            g_loss = gan.train_on_batch(lat_points,y_gan)
            
            
            #paint some pictures
            if epoch % 2 == 0:
                imgs = generator.predict(fixed_latent_points)

                #renormalize images for easy printing
                imgs = (imgs + 1) / 2.0
                train_images.append(imgs)
                
                #add loss to storage for graphing
                
                gan_loss.append(g_loss)
                disc_loss.append(d_loss)
            
            avg_epoch_disc_loss.append(d_loss)
            avg_epoch_gen_loss.append(g_loss)

        stop_time = time.time()
        print("avg loss over epoch, \nDiscriminator:" ,sum(avg_epoch_disc_loss)/len(avg_epoch_disc_loss),"\nGenerator:",sum(avg_epoch_gen_loss)/len(avg_epoch_gen_loss))
        print("epoch",epoch,"finished in",stop_time - start_time,"s\n\n")
            
            
    return train_images,gan_loss,disc_loss


reset_train = True

if reset_train:    
    discriminator = make_discriminator()
    generator = make_generator()

    gan = make_gan(discriminator,generator)



train_images,gan_loss,disc_loss = train_gan(data,gan,discriminator,generator,n_epochs=3000)
# Out:
# starting epoch 0
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# avg loss over epoch,
# Discriminator: 0.6793320377667745
# Generator: 0.6916858951250712
# epoch 0 finished in 3.9287641048431396 s
#
#
# starting epoch 1
# avg loss over epoch,
# Discriminator: 0.5948811173439026
# Generator: 0.6623188853263855
# epoch 1 finished in 0.5500814914703369 s
#
#
# starting epoch 2
# avg loss over epoch,
# Discriminator: 0.6106558044751486
# Generator: 0.5368929505348206
# epoch 2 finished in 0.5504601001739502 s
#
#
# starting epoch 3
# avg loss over epoch,
# Discriminator: 0.636704703172048
# Generator: 0.6481112639109293
# epoch 3 finished in 0.55094313621521 s
#
#
# starting epoch 4
# avg loss over epoch,
# Discriminator: 0.496165007352829
# Generator: 1.0165606538454692
# epoch 4 finished in 0.559612512588501 s
#
#
# starting epoch 5
# avg loss over epoch,
# Discriminator: 0.372560054063797
# Generator: 1.3190816243489583
# epoch 5 finished in 0.5434587001800537 s
#
#
# starting epoch 6
# avg loss over epoch,
# Discriminator: 0.4344513813654582
# Generator: 0.8995131850242615
# epoch 6 finished in 0.5663528442382812 s
#
#
# starting epoch 7
# avg loss over epoch,
# Discriminator: 0.4484630326430003
# Generator: 0.730462928613027
# epoch 7 finished in 0.5400047302246094 s
#
#
# starting epoch 8
# avg loss over epoch,
# Discriminator: 0.40035932262738544
# Generator: 0.7619265913963318
# epoch 8 finished in 0.5572021007537842 s
#
#
# starting epoch 9
# avg loss over epoch,
# Discriminator: 0.3754168550173442
# Generator: 0.7683030168215433
# epoch 9 finished in 0.5445592403411865 s
#
#
# starting epoch 10
# avg loss over epoch,
# Discriminator: 0.613769511381785
# Generator: 0.5644800066947937
# epoch 10 finished in 0.5693936347961426 s
#
#
# starting epoch 11
# avg loss over epoch,
# Discriminator: 0.4557211995124817
# Generator: 1.2148728370666504
# epoch 11 finished in 0.5391712188720703 s
#
#
# starting epoch 12
# avg loss over epoch,
# Discriminator: 0.37746407588322956
# Generator: 1.1019219160079956
# epoch 12 finished in 0.5627541542053223 s
#
#
# starting epoch 13
# avg loss over epoch,
# Discriminator: 0.4047277569770813
# Generator: 0.753027061621348
# epoch 13 finished in 0.5463135242462158 s
#
#
# starting epoch 14
# avg loss over epoch,
# Discriminator: 0.3914327522118886
# Generator: 1.0013089974721272
# epoch 14 finished in 0.5644519329071045 s
#
#
# starting epoch 15
# avg loss over epoch,
# Discriminator: 0.3183373808860779
# Generator: 1.2413989305496216
# epoch 15 finished in 0.5383837223052979 s
#
#
# starting epoch 16
# avg loss over epoch,
# Discriminator: 0.5065590341885885
# Generator: 1.0375736157099407
# epoch 16 finished in 0.5707581043243408 s
#
#
# starting epoch 17
# avg loss over epoch,
# Discriminator: 0.5740367968877157
# Generator: 1.3243454297383626
# epoch 17 finished in 0.5393610000610352 s
#
#
# starting epoch 18
# avg loss over epoch,
# Discriminator: 0.3805215160051982
# Generator: 1.3195548057556152
# epoch 18 finished in 0.562175989151001 s
#
#
# starting epoch 19
# avg loss over epoch,
# Discriminator: 0.3948664863904317
# Generator: 1.3164507150650024
# epoch 19 finished in 0.5604963302612305 s
#
#
# starting epoch 20
# avg loss over epoch,
# Discriminator: 0.4084141453107198
# Generator: 1.2463799715042114
# epoch 20 finished in 0.5481216907501221 s
#
#
# starting epoch 21
# avg loss over epoch,
# Discriminator: 0.32846205433209735
# Generator: 1.33438773949941
# epoch 21 finished in 0.5524024963378906 s
#
#
# starting epoch 22
# avg loss over epoch,
# Discriminator: 0.3519968589146932
# Generator: 1.689824104309082
# epoch 22 finished in 0.5506293773651123 s
#
#
# starting epoch 23
# avg loss over epoch,
# Discriminator: 0.20987464984258017
# Generator: 1.9552971522013347
# epoch 23 finished in 0.5460953712463379 s
#
#
# starting epoch 24
# avg loss over epoch,
# Discriminator: 0.3405020435651143
# Generator: 1.2715628544489543
# epoch 24 finished in 0.5535848140716553 s
#
#
# starting epoch 25
# avg loss over epoch,
# Discriminator: 0.32388540108998615
# Generator: 1.8568602005640666
# epoch 25 finished in 0.5463120937347412 s
#
#
# starting epoch 26
# avg loss over epoch,
# Discriminator: 0.34670673807462055
# Generator: 1.798528750737508
# epoch 26 finished in 0.5513591766357422 s
#
#
# starting epoch 27
# avg loss over epoch,
# Discriminator: 0.5699827969074249
# Generator: 1.4120155771573384
# epoch 27 finished in 0.5519719123840332 s
#
#
# starting epoch 28
# avg loss over epoch,
# Discriminator: 0.48969099919001263
# Generator: 1.8063472509384155
# epoch 28 finished in 0.5537898540496826 s
#
#
# starting epoch 29
# avg loss over epoch,
# Discriminator: 0.4289228320121765
# Generator: 1.8970927397410076
# epoch 29 finished in 0.5577096939086914 s
#
#
# starting epoch 30
# avg loss over epoch,
# Discriminator: 0.3300489584604899
# Generator: 2.310901959737142
# epoch 30 finished in 0.5585193634033203 s
#
#
# starting epoch 31
# avg loss over epoch,
# Discriminator: 0.6976190010706583
# Generator: 2.282425045967102
# epoch 31 finished in 0.5446338653564453 s
#
#
# starting epoch 32
# avg loss over epoch,
# Discriminator: 0.6791464885075887
# Generator: 1.9764169057210286
# epoch 32 finished in 0.5568983554840088 s
#
#
# starting epoch 33
# avg loss over epoch,
# Discriminator: 0.6614954074223837
# Generator: 1.3189215262730916
# epoch 33 finished in 0.5449192523956299 s
#
#
# starting epoch 34
# avg loss over epoch,
# Discriminator: 0.474342942237854
# Generator: 1.4361417690912883
# epoch 34 finished in 0.5656743049621582 s
#
#
# starting epoch 35
# avg loss over epoch,
# Discriminator: 0.43032656113306683
# Generator: 1.6789601643880208
# epoch 35 finished in 0.5437991619110107 s
#
#
# starting epoch 36
# avg loss over epoch,
# Discriminator: 0.38573097189267475
# Generator: 2.146903475125631
# epoch 36 finished in 0.5624823570251465 s
#
#
# starting epoch 37
# avg loss over epoch,
# Discriminator: 0.2973374327023824
# Generator: 2.33461332321167
# epoch 37 finished in 0.5387368202209473 s
#
#
# starting epoch 38
# avg loss over epoch,
# Discriminator: 0.1866787870724996
# Generator: 3.5653162797292075
# epoch 38 finished in 0.5682065486907959 s
#
#
# starting epoch 39
# avg loss over epoch,
# Discriminator: 0.2493856648604075
# Generator: 3.6579459508260093
# epoch 39 finished in 0.5422301292419434 s
#
#
# starting epoch 40
# avg loss over epoch,
# Discriminator: 0.4266562759876251
# Generator: 2.372067848841349
# epoch 40 finished in 0.5548205375671387 s
#
#
# starting epoch 41
# avg loss over epoch,
# Discriminator: 0.7162151137987772
# Generator: 1.2704808712005615
# epoch 41 finished in 0.543560266494751 s
#
#
# starting epoch 42
# avg loss over epoch,
# Discriminator: 0.6110690633455912
# Generator: 1.1521844069163005
# epoch 42 finished in 0.5601856708526611 s
#
#
# starting epoch 43
# avg loss over epoch,
# Discriminator: 0.49424925446510315
# Generator: 1.2036444346110027
# epoch 43 finished in 0.5409448146820068 s
#
#
# starting epoch 44
# avg loss over epoch,
# Discriminator: 0.5596393942832947
# Generator: 1.267281969388326
# epoch 44 finished in 0.5549333095550537 s
#
#
# starting epoch 45
# avg loss over epoch,
# Discriminator: 0.5090068380037943
# Generator: 1.5561916430791218
# epoch 45 finished in 0.5447094440460205 s
#
#
# starting epoch 46
# avg loss over epoch,
# Discriminator: 0.4891205628712972
# Generator: 1.4311415354410808
# epoch 46 finished in 0.5562460422515869 s
#
#
# starting epoch 47
# avg loss over epoch,
# Discriminator: 0.4470959007740021
# Generator: 1.475327690442403
# epoch 47 finished in 0.5394883155822754 s
#
#
# starting epoch 48
# avg loss over epoch,
# Discriminator: 0.393879234790802
# Generator: 1.5688802401224773
# epoch 48 finished in 0.5541667938232422 s
#
#
# starting epoch 49
# avg loss over epoch,
# Discriminator: 0.39756162961324054
# Generator: 1.5339053869247437
# epoch 49 finished in 0.5404074192047119 s
#
#
# starting epoch 50
# avg loss over epoch,
# Discriminator: 0.42698025703430176
# Generator: 1.5277034838994343
# epoch 50 finished in 0.5555288791656494 s
#
#
# starting epoch 51
# avg loss over epoch,
# Discriminator: 0.4477587143580119
# Generator: 1.4905623992284138
# epoch 51 finished in 0.5398061275482178 s
#
#
# starting epoch 52
# avg loss over epoch,
# Discriminator: 0.343536118666331
# Generator: 1.5451523462931316
# epoch 52 finished in 0.5642802715301514 s
#
#
# starting epoch 53
# avg loss over epoch,
# Discriminator: 0.4357999563217163
# Generator: 1.8420202334721882
# epoch 53 finished in 0.5362434387207031 s
#
#
# starting epoch 54
# avg loss over epoch,
# Discriminator: 0.3749630053838094
# Generator: 2.1812175114949546
# epoch 54 finished in 0.571434497833252 s
#
#
# starting epoch 55
# avg loss over epoch,
# Discriminator: 0.3803343375523885
# Generator: 0.944429894288381
# epoch 55 finished in 0.5406606197357178 s
#
#
# starting epoch 56
# avg loss over epoch,
# Discriminator: 0.3813905914624532
# Generator: 1.0820093949635823
# epoch 56 finished in 0.554527759552002 s
#
#
# starting epoch 57
# avg loss over epoch,
# Discriminator: 0.4173261324564616
# Generator: 1.2572869857152302
# epoch 57 finished in 0.5392558574676514 s
#
#
# starting epoch 58
# avg loss over epoch,
# Discriminator: 0.5219114720821381
# Generator: 1.4070370594660442
# epoch 58 finished in 0.5578546524047852 s
#
#
# starting epoch 59
# avg loss over epoch,
# Discriminator: 0.5397748549779257
# Generator: 1.4714659452438354
# epoch 59 finished in 0.5365822315216064 s
#
#
# starting epoch 60
# avg loss over epoch,
# Discriminator: 0.46942979097366333
# Generator: 1.6115875641504924
# epoch 60 finished in 0.5602588653564453 s
#
#
# starting epoch 61
# avg loss over epoch,
# Discriminator: 0.4088040391604106
# Generator: 1.5935490528742473
# epoch 61 finished in 0.5369627475738525 s
#
#
# starting epoch 62
# avg loss over epoch,
# Discriminator: 0.4414342741171519
# Generator: 1.5817803939183552
# epoch 62 finished in 0.5611774921417236 s
#
#
# starting epoch 63
# avg loss over epoch,
# Discriminator: 0.5001321732997894
# Generator: 1.6393272876739502
# epoch 63 finished in 0.5411431789398193 s
#
#
# starting epoch 64
# avg loss over epoch,
# Discriminator: 4.872848272323608
# Generator: 1.0513236373662949
# epoch 64 finished in 0.5545806884765625 s
#
#
# starting epoch 65
# avg loss over epoch,
# Discriminator: 1.9145206113656361
# Generator: 6.302762349446614
# epoch 65 finished in 0.5352158546447754 s
#
#
# starting epoch 66
# avg loss over epoch,
# Discriminator: 0.48188316822052
# Generator: 2.154813210169474
# epoch 66 finished in 0.5576677322387695 s
#
#
# starting epoch 67
# avg loss over epoch,
# Discriminator: 0.4426299035549164
# Generator: 1.1763837337493896
# epoch 67 finished in 0.5464603900909424 s
#
#
# starting epoch 68
# avg loss over epoch,
# Discriminator: 0.3876872956752777
# Generator: 1.1538068056106567
# epoch 68 finished in 0.5568771362304688 s
#
#
# starting epoch 69
# avg loss over epoch,
# Discriminator: 0.3617681860923767
# Generator: 1.15158212184906
# epoch 69 finished in 0.5398523807525635 s
#
#
# starting epoch 70
# avg loss over epoch,
# Discriminator: 0.36760478218396503
# Generator: 1.1342860857645671
# epoch 70 finished in 0.5518133640289307 s
#
#
# starting epoch 71
# avg loss over epoch,
# Discriminator: 0.3697291612625122
# Generator: 1.162208875020345
# epoch 71 finished in 0.5438024997711182 s
#
#
# starting epoch 72
# avg loss over epoch,
# Discriminator: 0.40425310532251996
# Generator: 1.0973965326944988
# epoch 72 finished in 0.5678398609161377 s
#
#
# starting epoch 73
# avg loss over epoch,
# Discriminator: 0.4788608153661092
# Generator: 0.9492692748705546
# epoch 73 finished in 0.5383772850036621 s
#
#
# starting epoch 74
# avg loss over epoch,
# Discriminator: 0.5588645935058594
# Generator: 0.7966163953145345
# epoch 74 finished in 0.5555758476257324 s
#
#
# starting epoch 75
# avg loss over epoch,
# Discriminator: 0.5293726126352946
# Generator: 0.8106017311414083
# epoch 75 finished in 0.5403852462768555 s
#
#
# starting epoch 76
# avg loss over epoch,
# Discriminator: 0.5076066255569458
# Generator: 0.8964703877766927
# epoch 76 finished in 0.5536549091339111 s
#
#
# starting epoch 77
# avg loss over epoch,
# Discriminator: 0.4487284719944
# Generator: 0.9974677364031473
# epoch 77 finished in 0.540264368057251 s
#
#
# starting epoch 78
# avg loss over epoch,
# Discriminator: 0.4143323600292206
# Generator: 1.0251729885737102
# epoch 78 finished in 0.5617539882659912 s
#
#
# starting epoch 79
# avg loss over epoch,
# Discriminator: 0.43206002314885456
# Generator: 1.049474040667216
# epoch 79 finished in 0.5387370586395264 s
#
#
# starting epoch 80
# avg loss over epoch,
# Discriminator: 0.4691763718922933
# Generator: 1.0542227029800415
# epoch 80 finished in 0.5585269927978516 s
#
#
# starting epoch 81
# avg loss over epoch,
# Discriminator: 0.5258978009223938
# Generator: 0.9671019713083903
# epoch 81 finished in 0.5385019779205322 s
#
#
# starting epoch 82
# avg loss over epoch,
# Discriminator: 0.5708428223927816
# Generator: 0.952302893002828
# epoch 82 finished in 0.5615887641906738 s
#
#
# starting epoch 83
# avg loss over epoch,
# Discriminator: 0.5180172622203827
# Generator: 1.0475026766459148
# epoch 83 finished in 0.5393240451812744 s
#
#
# starting epoch 84
# avg loss over epoch,
# Discriminator: 0.4262316823005676
# Generator: 1.3310929536819458
# epoch 84 finished in 0.5584592819213867 s
#
#
# starting epoch 85
# avg loss over epoch,
# Discriminator: 0.3588198522726695
# Generator: 1.5186975399653118
# epoch 85 finished in 0.5376989841461182 s
#
#
# starting epoch 86
# avg loss over epoch,
# Discriminator: 0.4015126923720042
# Generator: 1.695061484972636
# epoch 86 finished in 0.5684354305267334 s
#
#
# starting epoch 87
# avg loss over epoch,
# Discriminator: 0.36643845836321515
# Generator: 2.3843292395273843
# epoch 87 finished in 0.5367527008056641 s
#
#
# starting epoch 88
# avg loss over epoch,
# Discriminator: 0.631009598573049
# Generator: 2.17637832959493
# epoch 88 finished in 0.5560030937194824 s
#
#
# starting epoch 89
# avg loss over epoch,
# Discriminator: 0.8301304380098978
# Generator: 1.7530824740727742
# epoch 89 finished in 0.5412874221801758 s
#
#
# starting epoch 90
# avg loss over epoch,
# Discriminator: 0.6701657374699911
# Generator: 1.5558305581410725
# epoch 90 finished in 0.5620555877685547 s
#
#
# starting epoch 91
# avg loss over epoch,
# Discriminator: 0.4783109327157338
# Generator: 1.5436017513275146
# epoch 91 finished in 0.5402507781982422 s
#
#
# starting epoch 92
# avg loss over epoch,
# Discriminator: 0.40716538826624554
# Generator: 1.7749595244725545
# epoch 92 finished in 0.5595686435699463 s
#
#
# starting epoch 93
# avg loss over epoch,
# Discriminator: 0.38840123017628986
# Generator: 1.7393793662389119
# epoch 93 finished in 0.5369658470153809 s
#
#
# starting epoch 94
# avg loss over epoch,
# Discriminator: 0.39102035760879517
# Generator: 1.6870450576146443
# epoch 94 finished in 0.5558969974517822 s
#
#
# starting epoch 95
# avg loss over epoch,
# Discriminator: 0.49545860290527344
# Generator: 1.3806803226470947
# epoch 95 finished in 0.5361881256103516 s
#
#
# starting epoch 96
# avg loss over epoch,
# Discriminator: 0.5577812194824219
# Generator: 1.2081215381622314
# epoch 96 finished in 0.559680700302124 s
#
#
# starting epoch 97
# avg loss over epoch,
# Discriminator: 0.6562120119730631
# Generator: 0.9837666948636373
# epoch 97 finished in 0.5357358455657959 s
#
#
# starting epoch 98
# avg loss over epoch,
# Discriminator: 0.6074885129928589
# Generator: 0.8340477546056112
# epoch 98 finished in 0.5507433414459229 s
#
#
# starting epoch 99
# avg loss over epoch,
# Discriminator: 0.5538214047749838
# Generator: 0.9302520751953125
# epoch 99 finished in 0.5397796630859375 s
#
#
# starting epoch 100
# avg loss over epoch,
# Discriminator: 0.5019260247548422
# Generator: 0.966678520043691
# epoch 100 finished in 0.5620472431182861 s
#
#
# starting epoch 101
# avg loss over epoch,
# Discriminator: 0.5056931475798289
# Generator: 0.9877793391545614
# epoch 101 finished in 0.5400214195251465 s
#
#
# starting epoch 102
# avg loss over epoch,
# Discriminator: 0.519599457581838
# Generator: 1.082707683245341
# epoch 102 finished in 0.5549843311309814 s
#
#
# starting epoch 103
# avg loss over epoch,
# Discriminator: 0.49702078104019165
# Generator: 1.2140999635060628
# epoch 103 finished in 0.5449869632720947 s
#
#
# starting epoch 104
# avg loss over epoch,
# Discriminator: 0.47156522671381634
# Generator: 1.3364381790161133
# epoch 104 finished in 0.5586950778961182 s
#
#
# starting epoch 105
# avg loss over epoch,
# Discriminator: 0.4977978467941284
# Generator: 1.2318331797917683
# epoch 105 finished in 0.5352945327758789 s
#
#
# starting epoch 106
# avg loss over epoch,
# Discriminator: 0.447513868411382
# Generator: 1.3940404256184895
# epoch 106 finished in 0.5614500045776367 s
#
#
# starting epoch 107
# avg loss over epoch,
# Discriminator: 0.44915295640627545
# Generator: 1.3895499308904011
# epoch 107 finished in 0.5453240871429443 s
#
#
# starting epoch 108
# avg loss over epoch,
# Discriminator: 0.4545912941296895
# Generator: 1.373005708058675
# epoch 108 finished in 0.5538992881774902 s
#
#
# starting epoch 109
# avg loss over epoch,
# Discriminator: 0.41973883907000226
# Generator: 1.329799771308899
# epoch 109 finished in 0.5406959056854248 s
#
#
# starting epoch 110
# avg loss over epoch,
# Discriminator: 0.4102954665819804
# Generator: 1.3230127890904744
# epoch 110 finished in 0.568974494934082 s
#
#
# starting epoch 111
# avg loss over epoch,
# Discriminator: 0.36471649010976154
# Generator: 1.3781896034876506
# epoch 111 finished in 0.5369114875793457 s
#
#
# starting epoch 112
# avg loss over epoch,
# Discriminator: 0.3421323200066884
# Generator: 1.4763996203740437
# epoch 112 finished in 0.5538120269775391 s
#
#
# starting epoch 113
# avg loss over epoch,
# Discriminator: 0.35888675848642987
# Generator: 1.411655028661092
# epoch 113 finished in 0.5429897308349609 s
#
#
# starting epoch 114
# avg loss over epoch,
# Discriminator: 0.44689088066418964
# Generator: 1.1425366799036663
# epoch 114 finished in 0.5493838787078857 s
#
#
# starting epoch 115
# avg loss over epoch,
# Discriminator: 0.5545634428660074
# Generator: 1.2285106182098389
# epoch 115 finished in 0.5367515087127686 s
#
#
# starting epoch 116
# avg loss over epoch,
# Discriminator: 0.4397029181321462
# Generator: 2.0915434757868447
# epoch 116 finished in 0.5607292652130127 s
#
#
# starting epoch 117
# avg loss over epoch,
# Discriminator: 0.3167010347048442
# Generator: 1.5029258330663045
# epoch 117 finished in 0.5469496250152588 s
#
#
# starting epoch 118
# avg loss over epoch,
# Discriminator: 0.5075374444325765
# Generator: 1.2415640751520793
# epoch 118 finished in 0.5534782409667969 s
#
#
# starting epoch 119
# avg loss over epoch,
# Discriminator: 0.4721212486426036
# Generator: 1.6251623233159382
# epoch 119 finished in 0.536989688873291 s
#
#
# starting epoch 120
# avg loss over epoch,
# Discriminator: 0.3663523693879445
# Generator: 2.0913172562917075
# epoch 120 finished in 0.5597693920135498 s
#
#
# starting epoch 121
# avg loss over epoch,
# Discriminator: 0.3992731173833211
# Generator: 2.0367379983266196
# epoch 121 finished in 0.5376400947570801 s
#
#
# starting epoch 122
# avg loss over epoch,
# Discriminator: 0.35276589790980023
# Generator: 2.3314407666524253
# epoch 122 finished in 0.5573492050170898 s
#
#
# starting epoch 123
# avg loss over epoch,
# Discriminator: 0.3742190996805827
# Generator: 2.6059046586354575
# epoch 123 finished in 0.537355899810791 s
#
#
# starting epoch 124
# avg loss over epoch,
# Discriminator: 0.5174615780512491
# Generator: 3.0804402828216553
# epoch 124 finished in 0.560283899307251 s
#
#
# starting epoch 125
# avg loss over epoch,
# Discriminator: 0.5692126353581747
# Generator: 7.767322540283203
# epoch 125 finished in 0.5397939682006836 s
#
#
# starting epoch 126
# avg loss over epoch,
# Discriminator: 0.4862029552459717
# Generator: 12.682889302571615
# epoch 126 finished in 0.5505161285400391 s
#
#
# starting epoch 127
# avg loss over epoch,
# Discriminator: 0.6227275828520457
# Generator: 12.78678290049235
# epoch 127 finished in 0.5255465507507324 s
#
#
# starting epoch 128
# avg loss over epoch,
# Discriminator: 0.6251208881537119
# Generator: 2.1275158325831094
# epoch 128 finished in 0.552757978439331 s
#
#
# starting epoch 129
# avg loss over epoch,
# Discriminator: 0.6503750681877136
# Generator: 1.8351726531982422
# epoch 129 finished in 0.5404040813446045 s
#
#
# starting epoch 130
# avg loss over epoch,
# Discriminator: 0.663043757279714
# Generator: 1.2914365530014038
# epoch 130 finished in 0.5593807697296143 s
#
#
# starting epoch 131
# avg loss over epoch,
# Discriminator: 0.7849790255228678
# Generator: 1.0039005676905315
# epoch 131 finished in 0.5400922298431396 s
#
#
# starting epoch 132
# avg loss over epoch,
# Discriminator: 0.7378839453061422
# Generator: 0.8272391359011332
# epoch 132 finished in 0.551264762878418 s
#
#
# starting epoch 133
# avg loss over epoch,
# Discriminator: 0.7186452945073446
# Generator: 0.8322479526201884
# epoch 133 finished in 0.5434391498565674 s
#
#
# starting epoch 134
# avg loss over epoch,
# Discriminator: 0.6406501332918803
# Generator: 0.889898439248403
# epoch 134 finished in 0.5522022247314453 s
#
#
# starting epoch 135
# avg loss over epoch,
# Discriminator: 0.5772890051205953
# Generator: 0.9395174980163574
# epoch 135 finished in 0.5412716865539551 s
#
#
# starting epoch 136
# avg loss over epoch,
# Discriminator: 0.5200052460034689
# Generator: 0.9439364274342855
# epoch 136 finished in 0.5473544597625732 s
#
#
# starting epoch 137
# avg loss over epoch,
# Discriminator: 0.49488722284634906
# Generator: 1.0244818131128948
# epoch 137 finished in 0.5434532165527344 s
#
#
# starting epoch 138
# avg loss over epoch,
# Discriminator: 0.4603695074717204
# Generator: 1.1482348044713337
# epoch 138 finished in 0.5502438545227051 s
#
#
# starting epoch 139
# avg loss over epoch,
# Discriminator: 0.4751715362071991
# Generator: 1.109939416249593
# epoch 139 finished in 0.5365896224975586 s
#
#
# starting epoch 140
# avg loss over epoch,
# Discriminator: 0.4559455116589864
# Generator: 1.2401444514592488
# epoch 140 finished in 0.5509040355682373 s
#
#
# starting epoch 141
# avg loss over epoch,
# Discriminator: 0.4456181327501933
# Generator: 1.2205380996068318
# epoch 141 finished in 0.5421230792999268 s
#
#
# starting epoch 142
# avg loss over epoch,
# Discriminator: 0.43312763174374896
# Generator: 1.3332281510035198
# epoch 142 finished in 0.5518121719360352 s
#
#
# starting epoch 143
# avg loss over epoch,
# Discriminator: 0.4416116277376811
# Generator: 1.2641878525416057
# epoch 143 finished in 0.5361573696136475 s
#
#
# starting epoch 144
# avg loss over epoch,
# Discriminator: 0.5205594301223755
# Generator: 1.0627656777699788
# epoch 144 finished in 0.552396297454834 s
#
#
# starting epoch 145
# avg loss over epoch,
# Discriminator: 0.5144893626372019
# Generator: 1.1415375471115112
# epoch 145 finished in 0.5469012260437012 s
#
#
# starting epoch 146
# avg loss over epoch,
# Discriminator: 0.528607189655304
# Generator: 1.0399909416834514
# epoch 146 finished in 0.5513627529144287 s
#
#
# starting epoch 147
# avg loss over epoch,
# Discriminator: 0.4728097418944041
# Generator: 1.0889848868052165
# epoch 147 finished in 0.5392966270446777 s
#
#
# starting epoch 148
# avg loss over epoch,
# Discriminator: 0.4041061798731486
# Generator: 1.3309374650319417
# epoch 148 finished in 0.5525631904602051 s
#
#
# starting epoch 149
# avg loss over epoch,
# Discriminator: 0.4000546336174011
# Generator: 1.4923292398452759
# epoch 149 finished in 0.5362036228179932 s
#
#
# starting epoch 150
# avg loss over epoch,
# Discriminator: 0.39678635199864704
# Generator: 1.6530698935190837
# epoch 150 finished in 0.5535135269165039 s
#
#
# starting epoch 151
# avg loss over epoch,
# Discriminator: 0.35527459780375165
# Generator: 2.0442272822062173
# epoch 151 finished in 0.5363626480102539 s
#
#
# starting epoch 152
# avg loss over epoch,
# Discriminator: 0.3554445604483287
# Generator: 1.9352388381958008
# epoch 152 finished in 0.5554213523864746 s
#
#
# starting epoch 153
# avg loss over epoch,
# Discriminator: 0.3368290861447652
# Generator: 1.8555533091227214
# epoch 153 finished in 0.551476240158081 s
#
#
# starting epoch 154
# avg loss over epoch,
# Discriminator: 0.4238951603571574
# Generator: 1.5694504976272583
# epoch 154 finished in 0.5539605617523193 s
#
#
# starting epoch 155
# avg loss over epoch,
# Discriminator: 0.43322556217511493
# Generator: 1.6408425569534302
# epoch 155 finished in 0.5383386611938477 s
#
#
# starting epoch 156
# avg loss over epoch,
# Discriminator: 0.5104710261027018
# Generator: 1.5038618644078572
# epoch 156 finished in 0.5632190704345703 s
#
#
# starting epoch 157
# avg loss over epoch,
# Discriminator: 0.5398378173510233
# Generator: 1.41564937432607
# epoch 157 finished in 0.5391087532043457 s
#
#
# starting epoch 158
# avg loss over epoch,
# Discriminator: 0.4575147529443105
# Generator: 1.7479459444681804
# epoch 158 finished in 0.5566258430480957 s
#
#
# starting epoch 159
# avg loss over epoch,
# Discriminator: 0.3584287365277608
# Generator: 1.7924893299738567
# epoch 159 finished in 0.5392119884490967 s
#
#
# starting epoch 160
# avg loss over epoch,
# Discriminator: 0.38370440403620404
# Generator: 1.920103907585144
# epoch 160 finished in 0.5553302764892578 s
#
#
# starting epoch 161
# avg loss over epoch,
# Discriminator: 0.5225125749905905
# Generator: 2.1855057875315347
# epoch 161 finished in 0.5355715751647949 s
#
#
# starting epoch 162
# avg loss over epoch,
# Discriminator: 0.5923770864804586
# Generator: 1.4845492839813232
# epoch 162 finished in 0.5591187477111816 s
#
#
# starting epoch 163
# avg loss over epoch,
# Discriminator: 0.5901069243748983
# Generator: 1.1477458079655964
# epoch 163 finished in 0.538794755935669 s
#
#
# starting epoch 164
# avg loss over epoch,
# Discriminator: 0.5137160023053488
# Generator: 1.24562672773997
# epoch 164 finished in 0.5509145259857178 s
#
#
# starting epoch 165
# avg loss over epoch,
# Discriminator: 0.4621832072734833
# Generator: 1.3008097807566326
# epoch 165 finished in 0.5385191440582275 s
#
#
# starting epoch 166
# avg loss over epoch,
# Discriminator: 0.4816691279411316
# Generator: 1.287814458211263
# epoch 166 finished in 0.561415433883667 s
#
#
# starting epoch 167
# avg loss over epoch,
# Discriminator: 0.4811924497286479
# Generator: 1.3139147758483887
# epoch 167 finished in 0.539684534072876 s
#
#
# starting epoch 168
# avg loss over epoch,
# Discriminator: 0.48011858264605206
# Generator: 1.244504690170288
# epoch 168 finished in 0.5590205192565918 s
#
#
# starting epoch 169
# avg loss over epoch,
# Discriminator: 0.46860215067863464
# Generator: 1.3722498814264934
# epoch 169 finished in 0.5351972579956055 s
#
#
# starting epoch 170
# avg loss over epoch,
# Discriminator: 0.41848158836364746
# Generator: 1.3020002444585164
# epoch 170 finished in 0.5643882751464844 s
#
#
# starting epoch 171
# avg loss over epoch,
# Discriminator: 0.4344532589117686
# Generator: 1.4253490368525188
# epoch 171 finished in 0.5387973785400391 s
#
#
# starting epoch 172
# avg loss over epoch,
# Discriminator: 0.3821754554907481
# Generator: 1.609157641728719
# epoch 172 finished in 0.5522773265838623 s
#
#
# starting epoch 173
# avg loss over epoch,
# Discriminator: 0.4096226195494334
# Generator: 1.5430721441904705
# epoch 173 finished in 0.5414350032806396 s
#
#
# starting epoch 174
# avg loss over epoch,
# Discriminator: 0.45673298835754395
# Generator: 1.3035529057184856
# epoch 174 finished in 0.5555901527404785 s
#
#
# starting epoch 175
# avg loss over epoch,
# Discriminator: 0.512749711672465
# Generator: 1.2339074611663818
# epoch 175 finished in 0.5428202152252197 s
#
#
# starting epoch 176
# avg loss over epoch,
# Discriminator: 0.47794713576634723
# Generator: 1.1124949057896931
# epoch 176 finished in 0.558549165725708 s
#
#
# starting epoch 177
# avg loss over epoch,
# Discriminator: 0.527286966641744
# Generator: 0.9981784025828043
# epoch 177 finished in 0.540041446685791 s
#
#
# starting epoch 178
# avg loss over epoch,
# Discriminator: 0.48984624942143756
# Generator: 1.1181217829386394
# epoch 178 finished in 0.5555398464202881 s
#
#
# starting epoch 179
# avg loss over epoch,
# Discriminator: 0.450280765692393
# Generator: 1.7985019286473591
# epoch 179 finished in 0.5396177768707275 s
#
#
# starting epoch 180
# avg loss over epoch,
# Discriminator: 0.23016581435998282
# Generator: 2.1832045714060464
# epoch 180 finished in 0.5587000846862793 s
#
#
# starting epoch 181
# avg loss over epoch,
# Discriminator: 0.23162641624609628
# Generator: 2.0457173585891724
# epoch 181 finished in 0.5347113609313965 s
#
#
# starting epoch 182
# avg loss over epoch,
# Discriminator: 0.2824495832125346
# Generator: 1.854738473892212
# epoch 182 finished in 0.5587005615234375 s
#
#
# starting epoch 183
# avg loss over epoch,
# Discriminator: 0.2881621519724528
# Generator: 2.1176274617513022
# epoch 183 finished in 0.5391831398010254 s
#
#
# starting epoch 184
# avg loss over epoch,
# Discriminator: 0.2322788933912913
# Generator: 2.3681726455688477
# epoch 184 finished in 0.56246018409729 s
#
#
# starting epoch 185
# avg loss over epoch,
# Discriminator: 0.2961808393398921
# Generator: 2.3634375731150308
# epoch 185 finished in 0.5362811088562012 s
#
#
# starting epoch 186
# avg loss over epoch,
# Discriminator: 0.3251832226912181
# Generator: 2.669204076131185
# epoch 186 finished in 0.5564661026000977 s
#
#
# starting epoch 187
# avg loss over epoch,
# Discriminator: 0.434884508450826
# Generator: 2.174486001332601
# epoch 187 finished in 0.5424106121063232 s
#
#
# starting epoch 188
# avg loss over epoch,
# Discriminator: 0.28063852588335675
# Generator: 2.208850860595703
# epoch 188 finished in 0.5517170429229736 s
#
#
# starting epoch 189
# avg loss over epoch,
# Discriminator: 0.28525708119074505
# Generator: 2.191004157066345
# epoch 189 finished in 0.5381789207458496 s
#
#
# starting epoch 190
# avg loss over epoch,
# Discriminator: 0.28137778242429096
# Generator: 2.356919209162394
# epoch 190 finished in 0.5545616149902344 s
#
#
# starting epoch 191
# avg loss over epoch,
# Discriminator: 0.6905816793441772
# Generator: 2.4306563436985016
# epoch 191 finished in 0.5433456897735596 s
#
#
# starting epoch 192
# avg loss over epoch,
# Discriminator: 0.6388697226842245
# Generator: 2.073656996091207
# epoch 192 finished in 0.54555344581604 s
#
#
# starting epoch 193
# avg loss over epoch,
# Discriminator: 0.3909531533718109
# Generator: 1.7675304015477498
# epoch 193 finished in 0.5409417152404785 s
#
#
# starting epoch 194
# avg loss over epoch,
# Discriminator: 0.42263272404670715
# Generator: 1.8358903725941975
# epoch 194 finished in 0.5488307476043701 s
#
#
# starting epoch 195
# avg loss over epoch,
# Discriminator: 0.5656589070955912
# Generator: 1.6430719296137493
# epoch 195 finished in 0.5411550998687744 s
#
#
# starting epoch 196
# avg loss over epoch,
# Discriminator: 0.506060391664505
# Generator: 1.5959609746932983
# epoch 196 finished in 0.5521290302276611 s
#
#
# starting epoch 197
# avg loss over epoch,
# Discriminator: 0.633205513159434
# Generator: 1.3370849291483562
# epoch 197 finished in 0.5413048267364502 s
#
#
# starting epoch 198
# avg loss over epoch,
# Discriminator: 0.6467388868331909
# Generator: 1.2928016185760498
# epoch 198 finished in 0.5445935726165771 s
#
#
# starting epoch 199
# avg loss over epoch,
# Discriminator: 0.5255139470100403
# Generator: 1.1690714756647747
# epoch 199 finished in 0.5400817394256592 s
#
#
# starting epoch 200
# avg loss over epoch,
# Discriminator: 0.5062705477078756
# Generator: 1.2450599273045857
# epoch 200 finished in 0.5485959053039551 s
#
#
# starting epoch 201
# avg loss over epoch,
# Discriminator: 0.465771625439326
# Generator: 1.282506267229716
# epoch 201 finished in 0.5461812019348145 s
#
#
# starting epoch 202
# avg loss over epoch,
# Discriminator: 0.476804514726003
# Generator: 1.3843929767608643
# epoch 202 finished in 0.5526456832885742 s
#
#
# starting epoch 203
# avg loss over epoch,
# Discriminator: 0.49227263530095416
# Generator: 1.2463699579238892
# epoch 203 finished in 0.5403473377227783 s
#
#
# starting epoch 204
# avg loss over epoch,
# Discriminator: 0.4975445767243703
# Generator: 1.4899310668309529
# epoch 204 finished in 0.5533487796783447 s
#
#
# starting epoch 205
# avg loss over epoch,
# Discriminator: 0.5685187578201294
# Generator: 1.1262561082839966
# epoch 205 finished in 0.5421106815338135 s
#
#
# starting epoch 206
# avg loss over epoch,
# Discriminator: 0.6324496269226074
# Generator: 1.1197433471679688
# epoch 206 finished in 0.5542409420013428 s
#
#
# starting epoch 207
# avg loss over epoch,
# Discriminator: 0.596355656782786
# Generator: 1.2674448887507122
# epoch 207 finished in 0.5402824878692627 s
#
#
# starting epoch 208
# avg loss over epoch,
# Discriminator: 0.5071889956792196
# Generator: 1.3707420031229656
# epoch 208 finished in 0.5601997375488281 s
#
#
# starting epoch 209
# avg loss over epoch,
# Discriminator: 0.5568786263465881
# Generator: 1.1779820919036865
# epoch 209 finished in 0.5442609786987305 s
#
#
# starting epoch 210
# avg loss over epoch,
# Discriminator: 0.5676450133323669
# Generator: 1.1693569421768188
# epoch 210 finished in 0.5495789051055908 s
#
#
# starting epoch 211
# avg loss over epoch,
# Discriminator: 0.555216908454895
# Generator: 1.0602293411890666
# epoch 211 finished in 0.5331916809082031 s
#
#
# starting epoch 212
# avg loss over epoch,
# Discriminator: 0.4852146903673808
# Generator: 1.190664569536845
# epoch 212 finished in 0.5566051006317139 s
#
#
# starting epoch 213
# avg loss over epoch,
# Discriminator: 0.4361400802930196
# Generator: 1.2489045063654582
# epoch 213 finished in 0.538609504699707 s
#
#
# starting epoch 214
# avg loss over epoch,
# Discriminator: 0.3971445659796397
# Generator: 1.3383012215296428
# epoch 214 finished in 0.5508303642272949 s
#
#
# starting epoch 215
# avg loss over epoch,
# Discriminator: 0.39575186371803284
# Generator: 1.3091321388880413
# epoch 215 finished in 0.5369729995727539 s
#
#
# starting epoch 216
# avg loss over epoch,
# Discriminator: 0.45926987131436664
# Generator: 1.3583295345306396
# epoch 216 finished in 0.558021068572998 s
#
#
# starting epoch 217
# avg loss over epoch,
# Discriminator: 0.5325557589530945
# Generator: 1.2745660146077473
# epoch 217 finished in 0.5328936576843262 s
#
#
# starting epoch 218
# avg loss over epoch,
# Discriminator: 0.5277719497680664
# Generator: 1.4226696491241455
# epoch 218 finished in 0.5547127723693848 s
#
#
# starting epoch 219
# avg loss over epoch,
# Discriminator: 0.48978157838185626
# Generator: 1.3270320097605388
# epoch 219 finished in 0.5363907814025879 s
#
#
# starting epoch 220
# avg loss over epoch,
# Discriminator: 0.4540667235851288
# Generator: 1.378566026687622
# epoch 220 finished in 0.5567588806152344 s
#
#
# starting epoch 221
# avg loss over epoch,
# Discriminator: 0.39374857147534686
# Generator: 1.4115428527196248
# epoch 221 finished in 0.5387685298919678 s
#
#
# starting epoch 222
# avg loss over epoch,
# Discriminator: 0.46903663873672485
# Generator: 1.294490933418274
# epoch 222 finished in 0.5473282337188721 s
#
#
# starting epoch 223
# avg loss over epoch,
# Discriminator: 0.5840768019358317
# Generator: 1.0649476051330566
# epoch 223 finished in 0.5464646816253662 s
#
#
# starting epoch 224
# avg loss over epoch,
# Discriminator: 0.5863448282082876
# Generator: 1.4125250180562336
# epoch 224 finished in 0.5519556999206543 s
#
#
# starting epoch 225
# avg loss over epoch,
# Discriminator: 0.43523786465326947
# Generator: 1.4721763134002686
# epoch 225 finished in 0.538200855255127 s
#
#
# starting epoch 226
# avg loss over epoch,
# Discriminator: 0.4429052472114563
# Generator: 1.3743208646774292
# epoch 226 finished in 0.5587906837463379 s
#
#
# starting epoch 227
# avg loss over epoch,
# Discriminator: 0.4863285720348358
# Generator: 1.3187545935312908
# epoch 227 finished in 0.5436110496520996 s
#
#
# starting epoch 228
# avg loss over epoch,
# Discriminator: 0.5003682176272074
# Generator: 1.2169510920842488
# epoch 228 finished in 0.548973560333252 s
#
#
# starting epoch 229
# avg loss over epoch,
# Discriminator: 0.4720726211865743
# Generator: 1.3420878648757935
# epoch 229 finished in 0.5370662212371826 s
#
#
# starting epoch 230
# avg loss over epoch,
# Discriminator: 0.5130027135213217
# Generator: 1.1539275248845418
# epoch 230 finished in 0.5475289821624756 s
#
#
# starting epoch 231
# avg loss over epoch,
# Discriminator: 0.4900105396906535
# Generator: 1.2955243190129597
# epoch 231 finished in 0.5434830188751221 s
#
#
# starting epoch 232
# avg loss over epoch,
# Discriminator: 0.4979570706685384
# Generator: 1.190291404724121
# epoch 232 finished in 0.5481662750244141 s
#
#
# starting epoch 233
# avg loss over epoch,
# Discriminator: 0.515815277894338
# Generator: 1.0790553490320842
# epoch 233 finished in 0.5450704097747803 s
#
#
# starting epoch 234
# avg loss over epoch,
# Discriminator: 0.5100522637367249
# Generator: 1.1896886825561523
# epoch 234 finished in 0.5496442317962646 s
#
#
# starting epoch 235
# avg loss over epoch,
# Discriminator: 0.46580610672632855
# Generator: 1.4348630905151367
# epoch 235 finished in 0.549044132232666 s
#
#
# starting epoch 236
# avg loss over epoch,
# Discriminator: 0.48471259077390033
# Generator: 1.6040534178415935
# epoch 236 finished in 0.5533144474029541 s
#
#
# starting epoch 237
# avg loss over epoch,
# Discriminator: 0.4231993059317271
# Generator: 1.9488356510798137
# epoch 237 finished in 0.5510838031768799 s
#
#
# starting epoch 238
# avg loss over epoch,
# Discriminator: 0.43102572361628216
# Generator: 1.4139248927434285
# epoch 238 finished in 0.5456349849700928 s
#
#
# starting epoch 239
# avg loss over epoch,
# Discriminator: 0.5181739727656046
# Generator: 1.2924288511276245
# epoch 239 finished in 0.542365550994873 s
#
#
# starting epoch 240
# avg loss over epoch,
# Discriminator: 0.4880736172199249
# Generator: 1.0842101176579793
# epoch 240 finished in 0.5467677116394043 s
#
#
# starting epoch 241
# avg loss over epoch,
# Discriminator: 0.5020864407221476
# Generator: 1.1037590901056926
# epoch 241 finished in 0.5538444519042969 s
#
#
# starting epoch 242
# avg loss over epoch,
# Discriminator: 0.5269447763760885
# Generator: 1.1642266511917114
# epoch 242 finished in 0.5474717617034912 s
#
#
# starting epoch 243
# avg loss over epoch,
# Discriminator: 0.5227881471316019
# Generator: 1.419962724049886
# epoch 243 finished in 0.5493264198303223 s
#
#
# starting epoch 244
# avg loss over epoch,
# Discriminator: 0.3543127477169037
# Generator: 1.7992018858591716
# epoch 244 finished in 0.558936595916748 s
#
#
# starting epoch 245
# avg loss over epoch,
# Discriminator: 0.5946547587712606
# Generator: 1.779643177986145
# epoch 245 finished in 0.5439560413360596 s
#
#
# starting epoch 246
# avg loss over epoch,
# Discriminator: 0.6856919328371683
# Generator: 1.6725807587305705
# epoch 246 finished in 0.5485098361968994 s
#
#
# starting epoch 247
# avg loss over epoch,
# Discriminator: 0.5222683747609457
# Generator: 1.8481677373250325
# epoch 247 finished in 0.5427212715148926 s
#
#
# starting epoch 248
# avg loss over epoch,
# Discriminator: 0.6377099355061849
# Generator: 1.5818665226300557
# epoch 248 finished in 0.552271842956543 s
#
#
# starting epoch 249
# avg loss over epoch,
# Discriminator: 0.6789393623669943
# Generator: 1.2658119996388753
# epoch 249 finished in 0.5420219898223877 s
#
#
# starting epoch 250
# avg loss over epoch,
# Discriminator: 0.6464823087056478
# Generator: 1.2175371646881104
# epoch 250 finished in 0.549924373626709 s
#
#
# starting epoch 251
# avg loss over epoch,
# Discriminator: 0.6197462479273478
# Generator: 1.0748003721237183
# epoch 251 finished in 0.5477497577667236 s
#
#
# starting epoch 252
# avg loss over epoch,
# Discriminator: 0.5549525221188863
# Generator: 1.2319717009862263
# epoch 252 finished in 0.5500905513763428 s
#
#
# starting epoch 253
# avg loss over epoch,
# Discriminator: 0.5118520259857178
# Generator: 1.1977148453394573
# epoch 253 finished in 0.5395796298980713 s
#
#
# starting epoch 254
# avg loss over epoch,
# Discriminator: 0.49801068504651386
# Generator: 1.2275757392247517
# epoch 254 finished in 0.5599503517150879 s
#
#
# starting epoch 255
# avg loss over epoch,
# Discriminator: 0.46417175730069477
# Generator: 1.329302708307902
# epoch 255 finished in 0.5446789264678955 s
#
#
# starting epoch 256
# avg loss over epoch,
# Discriminator: 0.4265473584334056
# Generator: 1.359227180480957
# epoch 256 finished in 0.5530307292938232 s
#
#
# starting epoch 257
# avg loss over epoch,
# Discriminator: 0.45316916704177856
# Generator: 1.3015963236490886
# epoch 257 finished in 0.5426239967346191 s
#
#
# starting epoch 258
# avg loss over epoch,
# Discriminator: 0.4787597159544627
# Generator: 1.323365052541097
# epoch 258 finished in 0.5497028827667236 s
#
#
# starting epoch 259
# avg loss over epoch,
# Discriminator: 0.48482897877693176
# Generator: 1.2939375638961792
# epoch 259 finished in 0.5409839153289795 s
#
#
# starting epoch 260
# avg loss over epoch,
# Discriminator: 0.525541732708613
# Generator: 1.2472474575042725
# epoch 260 finished in 0.5469598770141602 s
#
#
# starting epoch 261
# avg loss over epoch,
# Discriminator: 0.4547555148601532
# Generator: 1.3398974736531575
# epoch 261 finished in 0.5452215671539307 s
#
#
# starting epoch 262
# avg loss over epoch,
# Discriminator: 0.45776014526685077
# Generator: 1.4164515336354573
# epoch 262 finished in 0.5578138828277588 s
#
#
# starting epoch 263
# avg loss over epoch,
# Discriminator: 0.4083670675754547
# Generator: 1.3546169201533
# epoch 263 finished in 0.5335853099822998 s
#
#
# starting epoch 264
# avg loss over epoch,
# Discriminator: 0.42363084355990094
# Generator: 1.409808834393819
# epoch 264 finished in 0.5491485595703125 s
#
#
# starting epoch 265
# avg loss over epoch,
# Discriminator: 0.514409343401591
# Generator: 1.2895094553629558
# epoch 265 finished in 0.5422351360321045 s
#
#
# starting epoch 266
# avg loss over epoch,
# Discriminator: 0.5379465222358704
# Generator: 1.2271536191304524
# epoch 266 finished in 0.5569467544555664 s
#
#
# starting epoch 267
# avg loss over epoch,
# Discriminator: 0.4494858682155609
# Generator: 1.400424559911092
# epoch 267 finished in 0.5373740196228027 s
#
#
# starting epoch 268
# avg loss over epoch,
# Discriminator: 0.4055071572462718
# Generator: 1.4952830076217651
# epoch 268 finished in 0.553657054901123 s
#
#
# starting epoch 269
# avg loss over epoch,
# Discriminator: 0.40894315640131634
# Generator: 1.4216426213582356
# epoch 269 finished in 0.5408308506011963 s
#
#
# starting epoch 270
# avg loss over epoch,
# Discriminator: 0.4830634991327922
# Generator: 1.4923533995946248
# epoch 270 finished in 0.5609207153320312 s
#
#
# starting epoch 271
# avg loss over epoch,
# Discriminator: 0.5302494963010153
# Generator: 1.4486112197240193
# epoch 271 finished in 0.539109468460083 s
#
#
# starting epoch 272
# avg loss over epoch,
# Discriminator: 0.6008578737576803
# Generator: 1.344372550646464
# epoch 272 finished in 0.5547010898590088 s
#
#
# starting epoch 273
# avg loss over epoch,
# Discriminator: 0.5343630115191141
# Generator: 1.8635527690251668
# epoch 273 finished in 0.5366256237030029 s
#
#
# starting epoch 274
# avg loss over epoch,
# Discriminator: 0.547136664390564
# Generator: 1.5756441354751587
# epoch 274 finished in 0.552678108215332 s
#
#
# starting epoch 275
# avg loss over epoch,
# Discriminator: 0.5225888093312582
# Generator: 1.4064377546310425
# epoch 275 finished in 0.5396862030029297 s
#
#
# starting epoch 276
# avg loss over epoch,
# Discriminator: 0.6068041125933329
# Generator: 1.310273011525472
# epoch 276 finished in 0.5577008724212646 s
#
#
# starting epoch 277
# avg loss over epoch,
# Discriminator: 0.517412414153417
# Generator: 1.235527475674947
# epoch 277 finished in 0.5377562046051025 s
#
#
# starting epoch 278
# avg loss over epoch,
# Discriminator: 0.44141753514607746
# Generator: 1.4840364058812459
# epoch 278 finished in 0.5529041290283203 s
#
#
# starting epoch 279
# avg loss over epoch,
# Discriminator: 0.45019039511680603
# Generator: 1.323340614636739
# epoch 279 finished in 0.5388240814208984 s
#
#
# starting epoch 280
# avg loss over epoch,
# Discriminator: 0.5054844419161478
# Generator: 1.3547697464625041
# epoch 280 finished in 0.5549342632293701 s
#
#
# starting epoch 281
# avg loss over epoch,
# Discriminator: 0.5016064246495565
# Generator: 1.376756985982259
# epoch 281 finished in 0.5405552387237549 s
#
#
# starting epoch 282
# avg loss over epoch,
# Discriminator: 0.5165285368760427
# Generator: 1.3872599999109905
# epoch 282 finished in 0.553466796875 s
#
#
# starting epoch 283
# avg loss over epoch,
# Discriminator: 0.44225214918454486
# Generator: 1.5419100920359294
# epoch 283 finished in 0.5421569347381592 s
#
#
# starting epoch 284
# avg loss over epoch,
# Discriminator: 0.45650266607602435
# Generator: 1.4596900542577107
# epoch 284 finished in 0.5497732162475586 s
#
#
# starting epoch 285
# avg loss over epoch,
# Discriminator: 0.46164079507191974
# Generator: 1.4987141291300456
# epoch 285 finished in 0.5441064834594727 s
#
#
# starting epoch 286
# avg loss over epoch,
# Discriminator: 0.5008883277575175
# Generator: 1.3409254550933838
# epoch 286 finished in 0.5473158359527588 s
#
#
# starting epoch 287
# avg loss over epoch,
# Discriminator: 0.43745118379592896
# Generator: 1.553641398747762
# epoch 287 finished in 0.5466835498809814 s
#
#
# starting epoch 288
# avg loss over epoch,
# Discriminator: 0.41192248463630676
# Generator: 1.725038766860962
# epoch 288 finished in 0.546851634979248 s
#
#
# starting epoch 289
# avg loss over epoch,
# Discriminator: 0.46717708309491474
# Generator: 1.3274229764938354
# epoch 289 finished in 0.5406472682952881 s
#
#
# starting epoch 290
# avg loss over epoch,
# Discriminator: 0.523639072974523
# Generator: 1.4968514442443848
# epoch 290 finished in 0.5455739498138428 s
#
#
# starting epoch 291
# avg loss over epoch,
# Discriminator: 0.5853057106335958
# Generator: 1.4539014895757039
# epoch 291 finished in 0.5464246273040771 s
#
#
# starting epoch 292
# avg loss over epoch,
# Discriminator: 0.5247422258059183
# Generator: 1.3136808077494304
# epoch 292 finished in 0.5476782321929932 s
#
#
# starting epoch 293
# avg loss over epoch,
# Discriminator: 0.5250285267829895
# Generator: 1.2691303888956706
# epoch 293 finished in 0.5449929237365723 s
#
#
# starting epoch 294
# avg loss over epoch,
# Discriminator: 0.45608019828796387
# Generator: 1.4034788608551025
# epoch 294 finished in 0.5520081520080566 s
#
#
# starting epoch 295
# avg loss over epoch,
# Discriminator: 0.41351523995399475
# Generator: 1.316929777463277
# epoch 295 finished in 0.5442471504211426 s
#
#
# starting epoch 296
# avg loss over epoch,
# Discriminator: 0.5613848368326823
# Generator: 1.1878127654393513
# epoch 296 finished in 0.550257682800293 s
#
#
# starting epoch 297
# avg loss over epoch,
# Discriminator: 0.6566963394482931
# Generator: 1.2690421342849731
# epoch 297 finished in 0.5452685356140137 s
#
#
# starting epoch 298
# avg loss over epoch,
# Discriminator: 0.6302813092867533
# Generator: 1.0996096928914387
# epoch 298 finished in 0.5536899566650391 s
#
#
# starting epoch 299
# avg loss over epoch,
# Discriminator: 0.5835308233896891
# Generator: 1.0676675240198772
# epoch 299 finished in 0.537158727645874 s
#
#
# starting epoch 300
# avg loss over epoch,
# Discriminator: 0.5666155616442362
# Generator: 0.9958510994911194
# epoch 300 finished in 0.5504615306854248 s
#
#
# starting epoch 301
# avg loss over epoch,
# Discriminator: 0.5529079635938009
# Generator: 1.0715158383051555
# epoch 301 finished in 0.5427639484405518 s
#
#
# starting epoch 302
# avg loss over epoch,
# Discriminator: 0.47388025124867755
# Generator: 1.2028510173161824
# epoch 302 finished in 0.5523464679718018 s
#
#
# starting epoch 303
# avg loss over epoch,
# Discriminator: 0.45950689911842346
# Generator: 1.2400078376134236
# epoch 303 finished in 0.5391645431518555 s
#
#
# starting epoch 304
# avg loss over epoch,
# Discriminator: 0.5187505483627319
# Generator: 1.2811003923416138
# epoch 304 finished in 0.5590376853942871 s
#
#
# starting epoch 305
# avg loss over epoch,
# Discriminator: 0.4641428490479787
# Generator: 1.7627055247624714
# epoch 305 finished in 0.5488145351409912 s
#
#
# starting epoch 306
# avg loss over epoch,
# Discriminator: 0.4332134226957957
# Generator: 1.8540168205897014
# epoch 306 finished in 0.5516080856323242 s
#
#
# starting epoch 307
# avg loss over epoch,
# Discriminator: 0.6223153273264567
# Generator: 1.5820623238881428
# epoch 307 finished in 0.5436794757843018 s
#
#
# starting epoch 308
# avg loss over epoch,
# Discriminator: 0.6102783679962158
# Generator: 1.4456870158513386
# epoch 308 finished in 0.5576364994049072 s
#
#
# starting epoch 309
# avg loss over epoch,
# Discriminator: 0.5691365798314413
# Generator: 1.2527265946070354
# epoch 309 finished in 0.5375750064849854 s
#
#
# starting epoch 310
# avg loss over epoch,
# Discriminator: 0.6643356879552206
# Generator: 1.1048178672790527
# epoch 310 finished in 0.5522768497467041 s
#
#
# starting epoch 311
# avg loss over epoch,
# Discriminator: 0.5476869146029154
# Generator: 1.261112928390503
# epoch 311 finished in 0.5506114959716797 s
#
#
# starting epoch 312
# avg loss over epoch,
# Discriminator: 0.534592866897583
# Generator: 1.1055858135223389
# epoch 312 finished in 0.5485849380493164 s
#
#
# starting epoch 313
# avg loss over epoch,
# Discriminator: 0.5136611560980479
# Generator: 1.0976699193318684
# epoch 313 finished in 0.5371072292327881 s
#
#
# starting epoch 314
# avg loss over epoch,
# Discriminator: 0.4833177427450816
# Generator: 1.2414589325586955
# epoch 314 finished in 0.5567915439605713 s
#
#
# starting epoch 315
# avg loss over epoch,
# Discriminator: 0.4689015944798787
# Generator: 1.1780603726704915
# epoch 315 finished in 0.540675163269043 s
#
#
# ...
# epoch 2895 finished in 0.5413496494293213 s
#
#
# starting epoch 2896
# avg loss over epoch,
# Discriminator: 0.20145478596289954
# Generator: 3.580848137537638
# epoch 2896 finished in 0.5567488670349121 s
#
#
# starting epoch 2897
# avg loss over epoch,
# Discriminator: 0.17049982647101083
# Generator: 3.322453022003174
# epoch 2897 finished in 0.5346612930297852 s
#
#
# starting epoch 2898
# avg loss over epoch,
# Discriminator: 0.13880198200543722
# Generator: 3.460982004801432
# epoch 2898 finished in 0.5514748096466064 s
#
#
# starting epoch 2899
# avg loss over epoch,
# Discriminator: 0.12598876655101776
# Generator: 3.754942258199056
# epoch 2899 finished in 0.5471184253692627 s
#
#
# starting epoch 2900
# avg loss over epoch,
# Discriminator: 0.09885962307453156
# Generator: 3.7621476650238037
# epoch 2900 finished in 0.548530101776123 s
#
#
# starting epoch 2901
# avg loss over epoch,
# Discriminator: 0.10380092759927113
# Generator: 3.836702744166056
# epoch 2901 finished in 0.5389025211334229 s
#
#
# starting epoch 2902
# avg loss over epoch,
# Discriminator: 0.11419462909301122
# Generator: 3.5611093839009604
# epoch 2902 finished in 0.5499222278594971 s
#
#
# starting epoch 2903
# avg loss over epoch,
# Discriminator: 0.14684474716583887
# Generator: 3.7638376553853354
# epoch 2903 finished in 0.5395598411560059 s
#
#
# starting epoch 2904
# avg loss over epoch,
# Discriminator: 0.12859718004862467
# Generator: 3.671226739883423
# epoch 2904 finished in 0.5552420616149902 s
#
#
# starting epoch 2905
# avg loss over epoch,
# Discriminator: 0.12534152468045553
# Generator: 3.693087657292684
# epoch 2905 finished in 0.5371031761169434 s
#
#
# starting epoch 2906
# avg loss over epoch,
# Discriminator: 0.10760388274987538
# Generator: 3.5501534938812256
# epoch 2906 finished in 0.5518946647644043 s
#
#
# starting epoch 2907
# avg loss over epoch,
# Discriminator: 0.09900955855846405
# Generator: 4.1132214069366455
# epoch 2907 finished in 0.5390439033508301 s
#
#
# starting epoch 2908
# avg loss over epoch,
# Discriminator: 0.16816413402557373
# Generator: 3.719037135442098
# epoch 2908 finished in 0.5488419532775879 s
#
#
# starting epoch 2909
# avg loss over epoch,
# Discriminator: 0.13107872505982718
# Generator: 3.852743705113729
# epoch 2909 finished in 0.5370340347290039 s
#
#
# starting epoch 2910
# avg loss over epoch,
# Discriminator: 0.13520007332166037
# Generator: 3.862212816874186
# epoch 2910 finished in 0.5520205497741699 s
#
#
# starting epoch 2911
# avg loss over epoch,
# Discriminator: 0.11866696178913116
# Generator: 4.179573853810628
# epoch 2911 finished in 0.5352118015289307 s
#
#
# starting epoch 2912
# avg loss over epoch,
# Discriminator: 0.0940387671192487
# Generator: 3.365199089050293
# epoch 2912 finished in 0.5515477657318115 s
#
#
# starting epoch 2913
# avg loss over epoch,
# Discriminator: 0.11313215394814809
# Generator: 3.9865402380625405
# epoch 2913 finished in 0.5392270088195801 s
#
#
# starting epoch 2914
# avg loss over epoch,
# Discriminator: 0.12156754235426585
# Generator: 3.7310431798299155
# epoch 2914 finished in 0.5510320663452148 s
#
#
# starting epoch 2915
# avg loss over epoch,
# Discriminator: 0.10026129086812337
# Generator: 3.736086289087931
# epoch 2915 finished in 0.5403554439544678 s
#
#
# starting epoch 2916
# avg loss over epoch,
# Discriminator: 0.10137076675891876
# Generator: 3.7235020796457925
# epoch 2916 finished in 0.5466980934143066 s
#
#
# starting epoch 2917
# avg loss over epoch,
# Discriminator: 0.10972464581330617
# Generator: 3.9714340368906655
# epoch 2917 finished in 0.5395553112030029 s
#
#
# starting epoch 2918
# avg loss over epoch,
# Discriminator: 0.0992720474799474
# Generator: 3.595649798711141
# epoch 2918 finished in 0.5453879833221436 s
#
#
# starting epoch 2919
# avg loss over epoch,
# Discriminator: 0.12073636800050735
# Generator: 4.257946809132894
# epoch 2919 finished in 0.5374655723571777 s
#
#
# starting epoch 2920
# avg loss over epoch,
# Discriminator: 0.12200729052225749
# Generator: 3.6750295162200928
# epoch 2920 finished in 0.5478198528289795 s
#
#
# starting epoch 2921
# avg loss over epoch,
# Discriminator: 0.13186356921990713
# Generator: 3.6010146141052246
# epoch 2921 finished in 0.5503287315368652 s
#
#
# starting epoch 2922
# avg loss over epoch,
# Discriminator: 0.11905841529369354
# Generator: 3.7338485717773438
# epoch 2922 finished in 0.5489320755004883 s
#
#
# starting epoch 2923
# avg loss over epoch,
# Discriminator: 0.128794235487779
# Generator: 3.8885445594787598
# epoch 2923 finished in 0.5454452037811279 s
#
#
# starting epoch 2924
# avg loss over epoch,
# Discriminator: 0.13230585803588232
# Generator: 3.5156668027242026
# epoch 2924 finished in 0.548454761505127 s
#
#
# starting epoch 2925
# avg loss over epoch,
# Discriminator: 0.10447217524051666
# Generator: 4.0895460446675616
# epoch 2925 finished in 0.541978120803833 s
#
#
# starting epoch 2926
# avg loss over epoch,
# Discriminator: 0.12682070831457773
# Generator: 3.8002994855244956
# epoch 2926 finished in 0.5503311157226562 s
#
#
# starting epoch 2927
# avg loss over epoch,
# Discriminator: 0.12432735910018285
# Generator: 3.6694176197052
# epoch 2927 finished in 0.535477876663208 s
#
#
# starting epoch 2928
# avg loss over epoch,
# Discriminator: 0.09890563537677129
# Generator: 3.5644209384918213
# epoch 2928 finished in 0.5585532188415527 s
#
#
# starting epoch 2929
# avg loss over epoch,
# Discriminator: 0.11758920301993687
# Generator: 3.522370974222819
# epoch 2929 finished in 0.5436265468597412 s
#
#
# starting epoch 2930
# avg loss over epoch,
# Discriminator: 0.12933802853027979
# Generator: 3.892583688100179
# epoch 2930 finished in 0.5506446361541748 s
#
#
# starting epoch 2931
# avg loss over epoch,
# Discriminator: 0.12863139808177948
# Generator: 4.108597834904988
# epoch 2931 finished in 0.5333106517791748 s
#
#
# starting epoch 2932
# avg loss over epoch,
# Discriminator: 0.15899929155906042
# Generator: 3.3314975102742515
# epoch 2932 finished in 0.5548014640808105 s
#
#
# starting epoch 2933
# avg loss over epoch,
# Discriminator: 0.12512442469596863
# Generator: 4.042439381281535
# epoch 2933 finished in 0.5369846820831299 s
#
#
# starting epoch 2934
# avg loss over epoch,
# Discriminator: 0.10488277673721313
# Generator: 3.9600024223327637
# epoch 2934 finished in 0.5507011413574219 s
#
#
# starting epoch 2935
# avg loss over epoch,
# Discriminator: 0.08806466062863667
# Generator: 3.7659414609273276
# epoch 2935 finished in 0.531569242477417 s
#
#
# starting epoch 2936
# avg loss over epoch,
# Discriminator: 0.13663279016812643
# Generator: 3.680259943008423
# epoch 2936 finished in 0.5530753135681152 s
#
#
# starting epoch 2937
# avg loss over epoch,
# Discriminator: 0.11670853445927303
# Generator: 3.267576217651367
# epoch 2937 finished in 0.5341689586639404 s
#
#
# starting epoch 2938
# avg loss over epoch,
# Discriminator: 0.11833652357260387
# Generator: 3.8648675282796225
# epoch 2938 finished in 0.5497629642486572 s
#
#
# starting epoch 2939
# avg loss over epoch,
# Discriminator: 0.11248514304558437
# Generator: 3.686741272608439
# epoch 2939 finished in 0.5404996871948242 s
#
#
# starting epoch 2940
# avg loss over epoch,
# Discriminator: 0.09129369010527928
# Generator: 4.104671239852905
# epoch 2940 finished in 0.5459649562835693 s
#
#
# starting epoch 2941
# avg loss over epoch,
# Discriminator: 0.09001818050940831
# Generator: 3.6594650745391846
# epoch 2941 finished in 0.5405251979827881 s
#
#
# starting epoch 2942
# avg loss over epoch,
# Discriminator: 0.10140554110209148
# Generator: 4.8231024742126465
# epoch 2942 finished in 0.5510802268981934 s
#
#
# starting epoch 2943
# avg loss over epoch,
# Discriminator: 0.0953659638762474
# Generator: 3.760672410329183
# epoch 2943 finished in 0.5402593612670898 s
#
#
# starting epoch 2944
# avg loss over epoch,
# Discriminator: 0.0914838934938113
# Generator: 4.172249476114909
# epoch 2944 finished in 0.5442700386047363 s
#
#
# starting epoch 2945
# avg loss over epoch,
# Discriminator: 0.11780012895663579
# Generator: 4.183627287546794
# epoch 2945 finished in 0.5386819839477539 s
#
#
# starting epoch 2946
# avg loss over epoch,
# Discriminator: 0.1417656938234965
# Generator: 3.7171338399251304
# epoch 2946 finished in 0.5516469478607178 s
#
#
# starting epoch 2947
# avg loss over epoch,
# Discriminator: 0.15487452844778696
# Generator: 3.9326770305633545
# epoch 2947 finished in 0.5448336601257324 s
#
#
# starting epoch 2948
# avg loss over epoch,
# Discriminator: 0.13639811426401138
# Generator: 3.6436731020609536
# epoch 2948 finished in 0.5532512664794922 s
#
#
# starting epoch 2949
# avg loss over epoch,
# Discriminator: 0.10890460759401321
# Generator: 3.7727668285369873
# epoch 2949 finished in 0.539583683013916 s
#
#
# starting epoch 2950
# avg loss over epoch,
# Discriminator: 0.11479656646649043
# Generator: 3.516802708307902
# epoch 2950 finished in 0.5511569976806641 s
#
#
# starting epoch 2951
# avg loss over epoch,
# Discriminator: 0.11358600358168285
# Generator: 4.031980196634929
# epoch 2951 finished in 0.5415401458740234 s
#
#
# starting epoch 2952
# avg loss over epoch,
# Discriminator: 0.0982938048740228
# Generator: 3.9977636337280273
# epoch 2952 finished in 0.5524849891662598 s
#
#
# starting epoch 2953
# avg loss over epoch,
# Discriminator: 0.17652194698651633
# Generator: 3.6940558751424155
# epoch 2953 finished in 0.5371007919311523 s
#
#
# starting epoch 2954
# avg loss over epoch,
# Discriminator: 0.14485165973504385
# Generator: 3.747189442316691
# epoch 2954 finished in 0.5568506717681885 s
#
#
# starting epoch 2955
# avg loss over epoch,
# Discriminator: 0.13949980835119882
# Generator: 3.5153220494588218
# epoch 2955 finished in 0.5397417545318604 s
#
#
# starting epoch 2956
# avg loss over epoch,
# Discriminator: 0.1355367824435234
# Generator: 4.330752849578857
# epoch 2956 finished in 0.549598217010498 s
#
#
# starting epoch 2957
# avg loss over epoch,
# Discriminator: 0.11730204770962398
# Generator: 3.6427836418151855
# epoch 2957 finished in 0.5364489555358887 s
#
#
# starting epoch 2958
# avg loss over epoch,
# Discriminator: 0.11226669947306316
# Generator: 4.125386476516724
# epoch 2958 finished in 0.5566635131835938 s
#
#
# starting epoch 2959
# avg loss over epoch,
# Discriminator: 0.13982892533143362
# Generator: 3.5696562131245932
# epoch 2959 finished in 0.5405974388122559 s
#
#
# starting epoch 2960
# avg loss over epoch,
# Discriminator: 0.14240311086177826
# Generator: 3.8265203634897866
# epoch 2960 finished in 0.5558905601501465 s
#
#
# starting epoch 2961
# avg loss over epoch,
# Discriminator: 0.09187438090642293
# Generator: 3.8712991078694663
# epoch 2961 finished in 0.5339338779449463 s
#
#
# starting epoch 2962
# avg loss over epoch,
# Discriminator: 0.1143533264597257
# Generator: 4.1538199583689375
# epoch 2962 finished in 0.5521707534790039 s
#
#
# starting epoch 2963
# avg loss over epoch,
# Discriminator: 0.16799909621477127
# Generator: 4.270522117614746
# epoch 2963 finished in 0.5326228141784668 s
#
#
# starting epoch 2964
# avg loss over epoch,
# Discriminator: 0.1822897344827652
# Generator: 3.7722624142964682
# epoch 2964 finished in 0.5517477989196777 s
#
#
# starting epoch 2965
# avg loss over epoch,
# Discriminator: 0.11601425955692928
# Generator: 3.5460418860117593
# epoch 2965 finished in 0.5378592014312744 s
#
#
# starting epoch 2966
# avg loss over epoch,
# Discriminator: 0.09248843292395274
# Generator: 3.729104439417521
# epoch 2966 finished in 0.5525426864624023 s
#
#
# starting epoch 2967
# avg loss over epoch,
# Discriminator: 0.1274909203251203
# Generator: 4.117160399754842
# epoch 2967 finished in 0.5415694713592529 s
#
#
# starting epoch 2968
# avg loss over epoch,
# Discriminator: 0.11963352312644322
# Generator: 3.881272315979004
# epoch 2968 finished in 0.5455596446990967 s
#
#
# starting epoch 2969
# avg loss over epoch,
# Discriminator: 0.11517444004615147
# Generator: 3.513267914454142
# epoch 2969 finished in 0.5440008640289307 s
#
#
# starting epoch 2970
# avg loss over epoch,
# Discriminator: 0.12576178212960562
# Generator: 3.6257899602254233
# epoch 2970 finished in 0.5490818023681641 s
#
#
# starting epoch 2971
# avg loss over epoch,
# Discriminator: 0.12800652285416922
# Generator: 3.975967009862264
# epoch 2971 finished in 0.5408778190612793 s
#
#
# starting epoch 2972
# avg loss over epoch,
# Discriminator: 0.15800408522288004
# Generator: 4.572932243347168
# epoch 2972 finished in 0.5470640659332275 s
#
#
# starting epoch 2973
# avg loss over epoch,
# Discriminator: 0.16358280926942825
# Generator: 3.9611991246541343
# epoch 2973 finished in 0.5413711071014404 s
#
#
# starting epoch 2974
# avg loss over epoch,
# Discriminator: 0.14440501729647318
# Generator: 3.7673356533050537
# epoch 2974 finished in 0.5519015789031982 s
#
#
# starting epoch 2975
# avg loss over epoch,
# Discriminator: 0.17051933457454047
# Generator: 3.6056370735168457
# epoch 2975 finished in 0.537233829498291 s
#
#
# starting epoch 2976
# avg loss over epoch,
# Discriminator: 0.157468448082606
# Generator: 3.9412084420522056
# epoch 2976 finished in 0.5493202209472656 s
#
#
# starting epoch 2977
# avg loss over epoch,
# Discriminator: 0.13321231305599213
# Generator: 3.863250176111857
# epoch 2977 finished in 0.5331566333770752 s
#
#
# starting epoch 2978
# avg loss over epoch,
# Discriminator: 0.20471090078353882
# Generator: 3.4406593640645347
# epoch 2978 finished in 0.5505614280700684 s
#
#
# starting epoch 2979
# avg loss over epoch,
# Discriminator: 0.1672874391078949
# Generator: 3.9297049840291343
# epoch 2979 finished in 0.5350284576416016 s
#
#
# starting epoch 2980
# avg loss over epoch,
# Discriminator: 0.11361438284317653
# Generator: 3.5653937657674155
# epoch 2980 finished in 0.5529325008392334 s
#
#
# starting epoch 2981
# avg loss over epoch,
# Discriminator: 0.10263697057962418
# Generator: 3.8374149004618325
# epoch 2981 finished in 0.5370073318481445 s
#
#
# starting epoch 2982
# avg loss over epoch,
# Discriminator: 0.10165950904289882
# Generator: 4.190819104512532
# epoch 2982 finished in 0.5524086952209473 s
#
#
# starting epoch 2983
# avg loss over epoch,
# Discriminator: 0.1044983019431432
# Generator: 3.855692466100057
# epoch 2983 finished in 0.5369224548339844 s
#
#
# starting epoch 2984
# avg loss over epoch,
# Discriminator: 0.10415536413590114
# Generator: 3.5820181369781494
# epoch 2984 finished in 0.5507140159606934 s
#
#
# starting epoch 2985
# avg loss over epoch,
# Discriminator: 0.10310440510511398
# Generator: 4.184676726659139
# epoch 2985 finished in 0.5351054668426514 s
#
#
# starting epoch 2986
# avg loss over epoch,
# Discriminator: 0.11897921562194824
# Generator: 3.7260404427846274
# epoch 2986 finished in 0.5479505062103271 s
#
#
# starting epoch 2987
# avg loss over epoch,
# Discriminator: 0.08879813800255458
# Generator: 3.6893561681111655
# epoch 2987 finished in 0.5421171188354492 s
#
#
# starting epoch 2988
# avg loss over epoch,
# Discriminator: 0.10871512691179912
# Generator: 3.8369530042012534
# epoch 2988 finished in 0.5553455352783203 s
#
#
# starting epoch 2989
# avg loss over epoch,
# Discriminator: 0.09240266680717468
# Generator: 4.026931126912435
# epoch 2989 finished in 0.5370450019836426 s
#
#
# starting epoch 2990
# avg loss over epoch,
# Discriminator: 0.13158797224362692
# Generator: 3.6594738960266113
# epoch 2990 finished in 0.5456802845001221 s
#
#
# starting epoch 2991
# avg loss over epoch,
# Discriminator: 0.1319320946931839
# Generator: 3.9327937761942544
# epoch 2991 finished in 0.5371925830841064 s
#
#
# starting epoch 2992
# avg loss over epoch,
# Discriminator: 0.12059402962525685
# Generator: 3.8838839530944824
# epoch 2992 finished in 0.5503973960876465 s
#
#
# starting epoch 2993
# avg loss over epoch,
# Discriminator: 0.157028466463089
# Generator: 4.130664189656575
# epoch 2993 finished in 0.536245584487915 s
#
#
# starting epoch 2994
# avg loss over epoch,
# Discriminator: 0.17416832347710928
# Generator: 4.148898760477702
# epoch 2994 finished in 0.5451416969299316 s
#
#
# starting epoch 2995
# avg loss over epoch,
# Discriminator: 0.11479681730270386
# Generator: 4.437723477681478
# epoch 2995 finished in 0.5367400646209717 s
#
#
# starting epoch 2996
# avg loss over epoch,
# Discriminator: 0.1420904447635015
# Generator: 3.516621748606364
# epoch 2996 finished in 0.5532126426696777 s
#
#
# starting epoch 2997
# avg loss over epoch,
# Discriminator: 0.12300978600978851
# Generator: 3.7811125914255777
# epoch 2997 finished in 0.5391037464141846 s
#
#
# starting epoch 2998
# avg loss over epoch,
# Discriminator: 0.10455166300137837
# Generator: 4.023573875427246
# epoch 2998 finished in 0.5490844249725342 s
#
#
# starting epoch 2999
# avg loss over epoch,
# Discriminator: 0.11069850623607635
# Generator: 3.968789974848429
# epoch 2999 finished in 0.5291619300842285 s

# %%
plt.figure(figsize=(20,10))

plt.plot(gan_loss)
plt.plot(disc_loss)

plt.show()

# %%
from matplotlib import animation

ims = []
fig = plt.figure()
ax = fig.add_axes([0,0,1,1], frameon=False, aspect=1)
ax.set_xticks([]); ax.set_yticks([])

for train_ims in train_images:

    

    im_1 = plt.imshow(train_ims[0,:,:],vmin=0, vmax=1, animated=True) #add first image for test
    
    ims.append([im_1])
    #plt.pause(0.1) 

mp4_writer =  animation.writers['ffmpeg']
writer = mp4_writer(fps=24, metadata=dict(artist='Me'), bitrate=1800)


anim = animation.ArtistAnimation(fig,ims)
anim.save("test_gif_2.mp4", writer= writer)

# %%
fig,axs = plt.subplots(3,3)

print(axs.shape)

for i in range(axs.shape[0]):
    for j in range(axs.shape[1]):
        
        axs[i,j].set_xticks([])
        axs[i,j].set_yticks([])

images = []

#iterate ove images
for imgs in train_images:
    ims = [] 
    for i,img in enumerate(imgs):
        
        line = i%3
        col = int(i/3)
        ims.append(axs[line,col].imshow(img[:,:],vmin=0, vmax=1, animated=True))
    
    images.append(ims)

mp4_writer =  animation.writers['ffmpeg']
writer = mp4_writer(fps=24, metadata=dict(artist='Me'), bitrate=1800)

anim = animation.ArtistAnimation(fig,images)
anim.save("train_grid.mp4", writer= writer)
# Out:
# (3, 3)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-7a216e6d2dd4> in <module>()
#      26
#      27 anim = animation.ArtistAnimation(fig,images)
# ---> 28 anim.save("train_grid.mp4", writer= writer)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#    1171                     for anim, d in zip(all_anim, data):
#    1172                         # TODO: See if turning off blit is really necessary
# -> 1173                         anim._draw_next_frame(d, blit=False)
#    1174                     writer.grab_frame(**savefig_kwargs)
#    1175
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#    1209         self._pre_draw(framedata, blit)
#    1210         self._draw_frame(framedata)
# -> 1211         self._post_draw(framedata, blit)
#    1212
#    1213     def _init_draw(self):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/animation.py in _post_draw(self, framedata, blit)
#    1234             self._blit_draw(self._drawn_artists, self._blit_cache)
#    1235         else:
# -> 1236             self._fig.canvas.draw_idle()
#    1237
#    1238     # The rest of the code in this class is to facilitate easy blitting
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1897         if not self._is_idle_drawing:
#    1898             with self._idle_draw_cntx():
# -> 1899                 self.draw(*args, **kwargs)
#    1900
#    1901     def draw_cursor(self, event):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2626             renderer.stop_rasterizing()
#    2627
# -> 2628         mimage._draw_list_compositing_images(renderer, self, artists)
#    2629
#    2630         renderer.close_group('axes')
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py in draw(self, renderer, *args, **kwargs)
#     562         # if not visible, declare victory and return
#     563         if not self.get_visible():
# --> 564             self.stale = False
#     565             return
#     566
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in stale(self, val)
#     223         return self._stale
#     224
# --> 225     @stale.setter
#     226     def stale(self, val):
#     227         self._stale = val
#
# KeyboardInterrupt:

# %%
points = generate_latent_points(9)
im_pred = generator.predict(points)
im_pred = (im_pred+1) /2.0

for i,im in enumerate(im_pred):
    plt.subplot(3,3,i+1)
    plt.imshow(im)

plt.show()
